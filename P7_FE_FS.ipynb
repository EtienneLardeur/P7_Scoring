# %% [markdown]
# # Introduction
#
# Our notebooks have been initialized thanks to several sources provided around the Home Credit default risk [Kaggle](https://www.kaggle.com/c/home-credit-default-risk) competition: data from Home Credit, Kernels-Notebooks from competitors, Discussions threads involving host and competitors.
#
# While the objective of competitors is to get the best AUC score _Area under the ROC Curve_ by *__any means__*, we'll rather focuse on the ability to provide *__interpretable__* decisions, including the possibility given to customers to explore their case.
#
# # Notebooks & dashboard
#
# There are 4 different notebooks:
# * __P7_EDA__: focusing on Exploratory Data Analysis,
# * __Current : P7_FE_FS__: focusing on Feature engineering and a first model-agnostic Feature Selection,
# * __P7_Model__: focusing on scoring with model evaluation,
# * __P7_Interpretation__ : focusing on model interpretation,
# And a dashboard python file.
#
#
# # Data
#
# This diagram shows data relationship :
#
# <img src="https://storage.googleapis.com/kaggle-media/competitions/home-credit/home_credit.png" class="svg" alt="" width="700" height="700">
#
# There are 7 different sources of data:
# Current application:
# * __application__: details about each `SK_ID_CURR` loan application and applicant + `TARGET` indicating the risk of failure to repay loan on time.
# * __test__: where the `TARGET` has not been calculated yet.
#
# External previous credits information:
# * __bureau__: details about each `SK_ID_BUREAU` client's previous credits oustide our company, with cardinality 1:n from current application.
# * __bureau_balance__: monthly details of each `SK_ID_BUREAU`.
# Internal previous credit information:
# * __previous_application__: details about each `SK_ID_PREV` client's previous credits applications within our company, with cardinality 1:n from current application.
# * __POS_CASH_balance__: monthly details of each `SK_ID_PREV` (credits or cash types).
# * __credit_card_balance__: monthly details of each `SK_ID_PREV` (credit cards revolving type).
# * __installments_payment__: payment history of each `SK_ID_PREV`.
#
# Moreover, we are provided with the features definitions (in `HomeCredit_columns_description.csv`).
#
# # Forewords
#
# In this FE notebook, we process datasets aggregation in order to get to an intermediate __fully understandable__ dataset, i.e. with any feature dealing with relevant details that could be discussed by counsellor in front of an applicant.
# This will surely affect the ability to reach the amazing scores of Kaggle competitors, and it implies to spend additionnal time for FE.<br/>
# Furthermore, we have to consider this task according to the expectations of the study, which consists in performing __model optimization__ and __model interpretation__. <br/>
# This will lead to consider as further optional tasks many EDA & FE ideas, in order to use __model__ and its __interpretation__ bring value in that perspective. <br/>

# %% [markdown]
# ## Imports

# %%
# %load_ext pycodestyle_magic
# %flake8_on
# PEP8 tested
# turn off in case of dataprep.eda use

# %%
# numpy and pandas for data manipulation
import numpy as np
import pandas as pd

# %%
# File system manangement
import os

# %%
# pickle
import pickle

# %%
# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# custom functions
from ipynb.fs.full.functions import plot_bar_gen, agg_numeric, heatmap, missing_values_table, count_categorical, convert_types, one_hot_encoder, label_encoder, target_corrs, target_corrs_corr, kde_plot

# %%
# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# paramètres
# to display any columns
pd.options.display.max_columns = 122
sns.set(style="ticks")
sns.set_style('whitegrid')

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy

# %% [markdown]
# ## Feature Engineering as done during EDA

# %% [markdown]
# A fist set of transformed datasets have been dumped with pickle files, we'll load them right before using those intermediate sources.

# %%
# load target (for correlation & Boruta study)
with open("Data/target.pkl", mode="rb") as df:
    target = pickle.load(df)

# %% [markdown]
# # Feature Engineering along a Bottom Up aggregation

# %% [markdown]
# ## Aggregate over Installments

# %%
# third level
installments = pd.read_csv('Data/installments_payments.csv')

# %% [markdown]
# While every payments are detailed over any previous application SK_ID_PREV, what matters for us, somehow already accessible through both credit balance or card balance with SK_DPD, is the rough info where (i.e. when and how much) a client failed to pay the installement.

# %%
# alternate option would be to put that missing info as X_STATUS
installments.dropna(inplace=True)

# %%
installments['DAYS_INSTALMENT'].min()
# Out:
# -2922.0

# %% [markdown]
# Let's catch overdue in time and amount :

# %%
# manual FE installements
# overdue amounts
installments['N_INS_AMT_OVERDUE'] = installments['AMT_INSTALMENT'] - installments['AMT_PAYMENT']
installments['N_INS_AMT_OVERDUE'] = installments['N_INS_AMT_OVERDUE'].apply(lambda x: x if x > 0 else 0)
# prepayed amounts
installments['N_INS_AMT_PREPAYED'] = installments['AMT_PAYMENT'] - installments['AMT_INSTALMENT']
installments['N_INS_AMT_PREPAYED'] = installments['N_INS_AMT_PREPAYED'].apply(lambda x: x if x > 0 else 0)
# overdue ratio
installments['N_AMT_OVERDUE_RATIO'] = installments['N_INS_AMT_OVERDUE'] / (1 + installments['AMT_INSTALMENT'])
# with positive values to get a match with SK_DPD
installments['N_INS_DPD'] = installments['DAYS_ENTRY_PAYMENT'] - installments['DAYS_INSTALMENT']
installments['N_INS_DPD'] = installments['N_INS_DPD'].apply(lambda x: x if x > 0 else 0)
# same with DBD Before Due may be somehow valuable
installments['N_INS_DBD'] = installments['DAYS_INSTALMENT'] - installments['DAYS_ENTRY_PAYMENT']
installments['N_INS_DBD'] = installments['N_INS_DBD'].apply(lambda x: x if x > 0 else 0)
# DPD categories to get a match with Bureau data
bins = [-np.inf, 1, 30, 60, 90, 120, np.inf]
values = ['0', '1', '2', '3', '4', '5']
installments['N_STATUS'] = pd.cut(installments['N_INS_DPD'], bins, labels=values)

# %%
# to get earliness of overdue we need to catch min of NUM_INSTALMENT_NUMBER out of !=0 N_STATUS
focus_installments = installments[installments['N_STATUS'] != '0']
focus_installments_agg = focus_installments.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'NUM_INSTALMENT_NUMBER': ['min']})
focus_installments_agg.columns = [
    'SK_ID_PREV',
    'INS_N_PREV_EARLIER_OVERDUE']

# %% [markdown]
# The less this "earlier overdue" is, the more is the risk of failure. But from Null value point of view, we won't be able to set a right replacement value for clients with no overdue at all : let's first consider other aggregative data to compute a valid overdue earliness index.

# %%
# compute valuable features by SK_ID_PREV
installments_agg = installments.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'NUM_INSTALMENT_VERSION': ['max'],
     'N_INS_AMT_OVERDUE': ['max'],
     'NUM_INSTALMENT_NUMBER': ['max'],
     'DAYS_INSTALMENT': ['max']})
installments_agg.columns = [
    'SK_ID_PREV',
    'INS_N_PREV_CNT_PROLONG',
    'INS_N_PREV_INS_AMT_MAX_OVERDUE',
    'INS_N_PREV_CNT_TOT_INSTALMENT',
    'INS_N_PREV_LAST_DAYS_INSTALMENT']

# %%
# merge with raw earlier overdue
installments_agg = installments_agg.merge(focus_installments_agg, how='left', on='SK_ID_PREV')
# we compute a ratio with ability to fill Null with Zero after aggregation
installments_agg['INS_N_PREV_EARLINESS_OVERDUE_RATIO'] = 1 - installments_agg['INS_N_PREV_EARLIER_OVERDUE'] / installments_agg['INS_N_PREV_CNT_TOT_INSTALMENT']
installments_agg.drop(columns=['INS_N_PREV_EARLIER_OVERDUE'], inplace=True)
installments_agg['INS_N_PREV_EARLINESS_OVERDUE_RATIO'].fillna(0, inplace=True)
installments_agg['INS_N_PREV_LOAN_AGE'] = - installments_agg['INS_N_PREV_LAST_DAYS_INSTALMENT'] / 365

# %%
installments_agg.columns
# Out:
# Index(['SK_ID_PREV', 'INS_N_PREV_CNT_PROLONG',
#        'INS_N_PREV_INS_AMT_MAX_OVERDUE', 'INS_N_PREV_CNT_TOT_INSTALMENT',
#        'INS_N_PREV_LAST_DAYS_INSTALMENT', 'INS_N_PREV_EARLINESS_OVERDUE_RATIO',
#        'INS_N_PREV_LOAN_AGE'],
#       dtype='object')

# %%
# merge with installments
installments_agg = installments_agg.merge(
    installments.filter(['SK_ID_CURR', 'SK_ID_PREV']),
    how='left',
    on='SK_ID_PREV')

# %%
# Preprocess installments_agg 
def installments_agg_id(ins, num_rows = None, nan_as_category = True):
    # General aggregations
    ins.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    ins_agg = ins.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    ins_agg.columns = pd.Index(['INSAGG_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    return ins_agg

# %%
# installements FE by SK_ID
sk_id_installments_agg = installments_agg_id(installments_agg, num_rows=None)

# %%
del installments_agg
del focus_installments_agg

# %%
installments.dtypes
# Out:
# SK_ID_PREV                   int64
# SK_ID_CURR                   int64
# NUM_INSTALMENT_VERSION     float64
# NUM_INSTALMENT_NUMBER        int64
# DAYS_INSTALMENT            float64
# DAYS_ENTRY_PAYMENT         float64
# AMT_INSTALMENT             float64
# AMT_PAYMENT                float64
# N_INS_AMT_OVERDUE          float64
# N_INS_AMT_PREPAYED         float64
# N_AMT_OVERDUE_RATIO        float64
# N_INS_DPD                  float64
# N_INS_DBD                  float64
# N_STATUS                  category
# dtype: object

# %%
# object type represents category
installments['N_STATUS'] = installments['N_STATUS'].astype('object')

# %%
# Preprocess installments_payments.csv
def installments_payments(ins, num_rows=None, nan_as_category=False):
    ins, cat_cols = one_hot_encoder(ins, nan_as_category=False)
    # Features: Perform aggregations
    aggregations = {
        'DAYS_INSTALMENT': ['mean'],
        'DAYS_ENTRY_PAYMENT': ['max'],
        'N_INS_DPD': ['max', 'mean', 'sum', 'var'],
        'N_INS_DBD': ['mean'],
        'N_INS_AMT_OVERDUE': ['mean'],
        'N_AMT_OVERDUE_RATIO': ['max', 'mean'],
        'AMT_INSTALMENT': ['max', 'mean', 'sum']
    }
    for cat in cat_cols:
        aggregations[cat] = ['sum']
    ins_agg = ins.groupby('SK_ID_CURR').agg(aggregations)
    ins_agg.columns = pd.Index(['INS_' + e[0] + "_" + e[1].upper() for e in ins_agg.columns.tolist()])
    # Count installments accounts
    ins_agg['INS_N_INSTAL_COUNT'] = ins.groupby('SK_ID_CURR').size()
    return ins_agg

# %%
# installements FE by SK_ID
sk_id_installments = installments_payments(installments, num_rows=None)

# %%
del installments

# %%
sk_id_installments.shape
# Out:
# (339578, 20)

# %%
sk_id_installments.head(3)
# Out:
#             INS_DAYS_INSTALMENT_MEAN  INS_DAYS_ENTRY_PAYMENT_MAX  \
# SK_ID_CURR
# 100001                  -2187.714286                     -1628.0
# 100002                   -295.000000                       -49.0
# 100003                  -1378.160000                      -544.0
#
#             INS_N_INS_DPD_MAX  INS_N_INS_DPD_MEAN  INS_N_INS_DPD_SUM  \
# SK_ID_CURR
# 100001                   11.0            1.571429               11.0
# 100002                    0.0            0.000000                0.0
# 100003                    0.0            0.000000                0.0
#
#             INS_N_INS_DPD_VAR  INS_N_INS_DBD_MEAN  INS_N_INS_AMT_OVERDUE_MEAN  \
# SK_ID_CURR
# 100001              17.285714            8.857143                         0.0
# 100002               0.000000           20.421053                         0.0
# 100003               0.000000            7.160000                         0.0
#
#             INS_N_AMT_OVERDUE_RATIO_MAX  INS_N_AMT_OVERDUE_RATIO_MEAN  \
# SK_ID_CURR
# 100001                              0.0                           0.0
# 100002                              0.0                           0.0
# 100003                              0.0                           0.0
#
#             INS_AMT_INSTALMENT_MAX  INS_AMT_INSTALMENT_MEAN  \
# SK_ID_CURR
# 100001                   17397.900              5885.132143
# 100002                   53093.745             11559.247105
# 100003                  560835.360             64754.586000
#
#             INS_AMT_INSTALMENT_SUM  INS_N_STATUS_0_SUM  INS_N_STATUS_1_SUM  \
# SK_ID_CURR
# 100001                   41195.925                 6.0                   1
# 100002                  219625.695                19.0                   0
# 100003                 1618864.650                25.0                   0
#
#             INS_N_STATUS_2_SUM  INS_N_STATUS_3_SUM  INS_N_STATUS_4_SUM  \
# SK_ID_CURR
# 100001                       0                   0                   0
# 100002                       0                   0                   0
# 100003                       0                   0                   0
#
#             INS_N_STATUS_5_SUM  INS_N_INSTAL_COUNT
# SK_ID_CURR
# 100001                       0                   7
# 100002                       0                  19
# 100003                       0                  25

# %%
sk_id_installments['INS_N_FAULT_RATE'] = 1 - sk_id_installments['INS_N_STATUS_0_SUM'] / sk_id_installments['INS_N_INSTAL_COUNT']

# %%
sk_id_installments['INS_N_FAULT_GRAVITY'] = (
    sk_id_installments['INS_N_STATUS_1_SUM'] +
    2 * sk_id_installments['INS_N_STATUS_2_SUM'] +
    3 * sk_id_installments['INS_N_STATUS_3_SUM'] +
    4 * sk_id_installments['INS_N_STATUS_4_SUM'] +
    5 * sk_id_installments['INS_N_STATUS_5_SUM']) / sk_id_installments['INS_N_INSTAL_COUNT']

# %%
sk_id_installments['INS_N_FAULT_ADJ_RATE'] = (
    1 - (sk_id_installments['INS_N_FAULT_RATE'] / -2922)) * sk_id_installments['INS_N_FAULT_RATE']

# %%
sk_id_installments.drop(columns=[
    'INS_N_STATUS_1_SUM',
    'INS_N_STATUS_2_SUM',
    'INS_N_STATUS_3_SUM',
    'INS_N_STATUS_4_SUM',
    'INS_N_STATUS_5_SUM'], inplace=True)

# %%
# merge to target for corr study
ins_target = target.join(sk_id_installments, how='left', on='SK_ID_CURR')
ins_target_corrs = target_corrs(ins_target)

# %%
ins_target_corrs.head(43)
# Out:
#                          feature  abs_corr
# 16              INS_N_FAULT_RATE  0.070791
# 18          INS_N_FAULT_ADJ_RATE  0.070790
# 17           INS_N_FAULT_GRAVITY  0.067062
# 10  INS_N_AMT_OVERDUE_RATIO_MEAN  0.063052
# 9    INS_N_AMT_OVERDUE_RATIO_MAX  0.045680
# 1       INS_DAYS_INSTALMENT_MEAN  0.043423
# 8     INS_N_INS_AMT_OVERDUE_MEAN  0.037576
# 14            INS_N_STATUS_0_SUM  0.026999
# 15            INS_N_INSTAL_COUNT  0.021214
# 7             INS_N_INS_DBD_MEAN  0.021116
# 13        INS_AMT_INSTALMENT_SUM  0.019944
# 12       INS_AMT_INSTALMENT_MEAN  0.018380
# 4             INS_N_INS_DPD_MEAN  0.008937
# 5              INS_N_INS_DPD_SUM  0.006548
# 3              INS_N_INS_DPD_MAX  0.003841
# 11        INS_AMT_INSTALMENT_MAX  0.002309
# 2     INS_DAYS_ENTRY_PAYMENT_MAX  0.002298
# 0                     SK_ID_CURR  0.002108
# 6              INS_N_INS_DPD_VAR  0.001370

# %%
# most interesting feature study through plot
kde_plot(ins_target, 'INS_N_FAULT_RATE')

# %%
ins_target.isna().sum().head(3)
# Out:
# SK_ID_CURR                      0
# TARGET                          0
# INS_DAYS_INSTALMENT_MEAN    15876
# dtype: int64

# %% [markdown]
# Those installments aggregative data produce missing values once merged with SK_ID, meaning we have no previous internal knowledge about those clients before application.
# N_INS_INSTAL_COUNT is therefore zero for those 15876 SK_ID.

# %%
'''  boruta for feature relevance
# set index with SK_ID_CURR
ins_target = ins_target.set_index('SK_ID_CURR')
X_ = ins_target.drop(columns=['TARGET'])
y_ = ins_target['TARGET']
X_sample, _, y_sample, _ = train_test_split(
        X_,
        y_,
        stratify=y_,
        test_size=0.8,
        random_state=42)
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(X_sample)
X_sample = imputer.transform(X_sample)
# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=6)
# define Boruta feature selection method
feat_selector = BorutaPy(rf, n_estimators='auto', max_iter=15, verbose=2, random_state=42)
# find all relevant features - features should be selected
feat_selector.fit(X_sample, y_sample)
# call transform() on X to filter it down to selected features
X_filtered = feat_selector.transform(X_sample)
x = ins_target.drop(columns=['TARGET']).columns
y = feat_selector.ranking_
df = pd.DataFrame({'feature':x, 'rank':y})
df = df.sort_values(by=['rank'], ascending=True)
df
'''
# Out:
# "  boruta for feature relevance\n# set index with SK_ID_CURR\nins_target = ins_target.set_index('SK_ID_CURR')\nX_ = ins_target.drop(columns=['TARGET'])\ny_ = ins_target['TARGET']\nX_sample, _, y_sample, _ = train_test_split(\n        X_,\n        y_,\n        stratify=y_,\n        test_size=0.8,\n        random_state=42)\nfrom sklearn.impute import SimpleImputer\nimputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)\nimputer = imputer.fit(X_sample)\nX_sample = imputer.transform(X_sample)\n# define random forest classifier, with utilising all cores and\n# sampling in proportion to y labels\nrf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=6)\n# define Boruta feature selection method\nfeat_selector = BorutaPy(rf, n_estimators='auto', max_iter=15, verbose=2, random_state=42)\n# find all relevant features - features should be selected\nfeat_selector.fit(X_sample, y_sample)\n# call transform() on X to filter it down to selected features\nX_filtered = feat_selector.transform(X_sample)\nx = ins_target.drop(columns=['TARGET']).columns\ny = feat_selector.ranking_\ndf = pd.DataFrame({'feature':x, 'rank':y})\ndf = df.sort_values(by=['rank'], ascending=True)\ndf\n"

# %%
# calculer les corrélations entre features
corr = sk_id_installments.corr(method='pearson')
corr = pd.melt(corr.reset_index(), id_vars='index')
corr.columns = ['x', 'y', 'value']
# visualiser les corrélations entre features
heatmap(
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs(),
    color=corr['value']
)

# %% [markdown]
# ## Aggregate over Credit balance

# %% [markdown]
# Credit card brings much more complex features to handle than credit, mainly because the client could use it (or not) in many ways. To get straight to the point, we'll try to catch and keep only the big picture.

# %%
# third level
credit_balance = pd.read_csv('Data/POS_CASH_balance.csv')

# %%
credit_balance
# Out:
#           SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0            1803195      182943             -31            48.0
# 1            1715348      367990             -33            36.0
# 2            1784872      397406             -32            12.0
# 3            1903291      269225             -35            48.0
# 4            2341044      334279             -35            36.0
# ...              ...         ...             ...             ...
# 10001353     2448283      226558             -20             6.0
# 10001354     1717234      141565             -19            12.0
# 10001355     1283126      315695             -21            10.0
# 10001356     1082516      450255             -22            12.0
# 10001357     1259607      174278             -52            16.0
#
#           CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                          45.0               Active       0           0
# 1                          35.0               Active       0           0
# 2                           9.0               Active       0           0
# 3                          42.0               Active       0           0
# 4                          35.0               Active       0           0
# ...                         ...                  ...     ...         ...
# 10001353                    0.0               Active     843           0
# 10001354                    0.0               Active     602           0
# 10001355                    0.0               Active     609           0
# 10001356                    0.0               Active     614           0
# 10001357                    0.0            Completed       0           0
#
# [10001358 rows x 8 columns]

# %%
# clean df and focus on active months
credit_balance.dropna(inplace=True)
focus_credit_balance = credit_balance[credit_balance['NAME_CONTRACT_STATUS'] == 'Active']

# %%
# get an idea of filtering DPD effect
dpd_count = focus_credit_balance[focus_credit_balance['SK_DPD'] != 0].shape[0]
dpd_def_count = focus_credit_balance[focus_credit_balance['SK_DPD_DEF'] != 0].shape[0]
print('dpd_def tolerance filtering ratio: %f' %(dpd_def_count/dpd_count))
# Out:
# dpd_def tolerance filtering ratio: 0.393702

# %% [markdown]
# Almost 40% of actual overdue are filtered, due to low laon amounts ignored.

# %%
# get loan age - in months and term for each previous loan
focus_credit_balance = credit_balance[credit_balance['NAME_CONTRACT_STATUS'] == 'Active']
focus_credit_balance_agg = focus_credit_balance.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'MONTHS_BALANCE': ['min'],
     'CNT_INSTALMENT': ['size']})
focus_credit_balance_agg.columns = [
    'SK_ID_PREV',
    'POS_N_PREV_LOAN_AGE_MONTH',
    'POS_N_PREV_LOAN_TERM']
focus_credit_balance.drop(columns=['NAME_CONTRACT_STATUS'], inplace=True)

# %%
# to get earliness of DPD overdue we need to catch min of CNT_INSTALMENT with SK_DPD > 0
dpd_credit_balance = focus_credit_balance[focus_credit_balance['SK_DPD'] != 0]
dpd_credit_balance_agg = dpd_credit_balance.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'CNT_INSTALMENT': ['min']})
dpd_credit_balance_agg.columns = [
    'SK_ID_PREV',
    'POS_N_DPD_PREV_EARLIER_OVERDUE']

# %%
# to get earliness of DPD_DEF overdue we need to catch min of CNT_INSTALMENT with SK_DPD_DEF > 0
dpd_def_credit_balance = focus_credit_balance[focus_credit_balance['SK_DPD_DEF'] != 0]
dpd_def_credit_balance_agg = dpd_def_credit_balance.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'CNT_INSTALMENT': ['min']})
dpd_def_credit_balance_agg.columns = [
    'SK_ID_PREV',
    'POS_N_DPD_DEF_PREV_EARLIER_OVERDUE']

# %%
# merge with raw earlier overdue
credit_balance_agg = focus_credit_balance_agg.merge(dpd_credit_balance_agg, how='left', on='SK_ID_PREV')
credit_balance_agg = credit_balance_agg.merge(dpd_def_credit_balance_agg, how='left', on='SK_ID_PREV')

# %%
del dpd_credit_balance_agg
del dpd_def_credit_balance_agg

# %%
# manua FE
credit_balance_agg['POS_N_DPD_PREV_EARLINESS_OVERDUE_RATIO'] = 1 - credit_balance_agg['POS_N_DPD_PREV_EARLIER_OVERDUE'] / credit_balance_agg['POS_N_PREV_LOAN_TERM']
credit_balance_agg.drop(columns=['POS_N_DPD_PREV_EARLIER_OVERDUE'], inplace=True)
credit_balance_agg['POS_N_DPD_PREV_EARLINESS_OVERDUE_RATIO'].fillna(0, inplace=True)
credit_balance_agg['POS_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO'] = 1 - credit_balance_agg['POS_N_DPD_DEF_PREV_EARLIER_OVERDUE'] / credit_balance_agg['POS_N_PREV_LOAN_TERM']
credit_balance_agg.drop(columns=['POS_N_DPD_DEF_PREV_EARLIER_OVERDUE'], inplace=True)
credit_balance_agg['POS_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO'].fillna(0, inplace=True)
credit_balance_agg['POS_N_PREV_LOAN_AGE'] = - credit_balance_agg['POS_N_PREV_LOAN_AGE_MONTH'] / 12

# %% [markdown]
# credit_balance_agg will be merged later on SK_ID_PREV.

# %%
# Preprocess POS_CASH_balance.csv
def pos_cash(pos, num_rows = None, nan_as_category=False):
    # Features
    aggregations = {
        'MONTHS_BALANCE': ['max', 'mean'],
        'SK_DPD': ['min', 'max', 'mean'],
        'SK_DPD_DEF': ['min', 'max', 'mean']
    }
    pos_agg = pos.groupby('SK_ID_CURR').agg(aggregations)
    pos_agg.columns = pd.Index(['POS_' + e[0] + "_" + e[1].upper() for e in pos_agg.columns.tolist()])
    # Count pos cash accounts
    pos_agg['POS_N_POS_COUNT'] = pos.groupby('SK_ID_CURR').size()
    return pos_agg

# %%
# Preprocess POS_CASH_balance.csv
sk_id_focus_credit_balance = pos_cash(focus_credit_balance, num_rows=None)

# %%
del focus_credit_balance

# %%
# merge to target for corr study
pos_target = target.join(sk_id_focus_credit_balance, how='left', on='SK_ID_CURR')
target_corrs(pos_target)
# Out:
#                    feature  abs_corr
# 9          POS_N_POS_COUNT  0.035816
# 2  POS_MONTHS_BALANCE_MEAN  0.033448
# 7       POS_SK_DPD_DEF_MAX  0.018046
# 8      POS_SK_DPD_DEF_MEAN  0.009336
# 1   POS_MONTHS_BALANCE_MAX  0.005359
# 3           POS_SK_DPD_MIN  0.004939
# 5          POS_SK_DPD_MEAN  0.004899
# 4           POS_SK_DPD_MAX  0.004256
# 6       POS_SK_DPD_DEF_MIN  0.003984
# 0               SK_ID_CURR  0.002108

# %%
# most interesting feature study through plot
kde_plot(pos_target, 'POS_N_POS_COUNT')

# %%
pos_target.isna().sum().head(3)
# Out:
# SK_ID_CURR                    0
# TARGET                        0
# POS_MONTHS_BALANCE_MAX    18270
# dtype: int64

# %% [markdown]
# Those pos aggregative data produce missing values once merged with SK_ID, meaning we have no previous internal knowledge about those clients before application.
# POS_N_POS_COUNT is therefore zero for those 18270 SK_ID.

# %%
''' boruta for feature relevance
# set index with SK_ID_CURR
pos_target = pos_target.set_index('SK_ID_CURR')

X_ = pos_target.drop(columns=['TARGET'])
y_ = pos_target['TARGET']

X_sample, _, y_sample, _ = train_test_split(
        X_,
        y_,
        stratify=y_,
        test_size=0.8,
        random_state=42)

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)
imputer = imputer.fit(X_sample)
X_sample = imputer.transform(X_sample)

# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=6)

# define Boruta feature selection method
feat_selector = BorutaPy(rf, n_estimators='auto', max_iter=15, verbose=2, random_state=42)

# find all relevant features - features should be selected
feat_selector.fit(X_sample, y_sample)

# call transform() on X to filter it down to selected features
X_filtered = feat_selector.transform(X_sample)

x = pos_target.drop(columns=['TARGET']).columns
y = feat_selector.ranking_
df = pd.DataFrame({'feature':x, 'rank':y})

df = df.sort_values(by=['rank'], ascending=True)

df
'''
# Out:
# " boruta for feature relevance\n# set index with SK_ID_CURR\npos_target = pos_target.set_index('SK_ID_CURR')\n\nX_ = pos_target.drop(columns=['TARGET'])\ny_ = pos_target['TARGET']\n\nX_sample, _, y_sample, _ = train_test_split(\n        X_,\n        y_,\n        stratify=y_,\n        test_size=0.8,\n        random_state=42)\n\nfrom sklearn.impute import SimpleImputer\nimputer = SimpleImputer(missing_values=np.nan, strategy='mean',verbose=0)\nimputer = imputer.fit(X_sample)\nX_sample = imputer.transform(X_sample)\n\n# define random forest classifier, with utilising all cores and\n# sampling in proportion to y labels\nrf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=6)\n\n# define Boruta feature selection method\nfeat_selector = BorutaPy(rf, n_estimators='auto', max_iter=15, verbose=2, random_state=42)\n\n# find all relevant features - features should be selected\nfeat_selector.fit(X_sample, y_sample)\n\n# call transform() on X to filter it down to selected features\nX_filtered = feat_selector.transform(X_sample)\n\nx = pos_target.drop(columns=['TARGET']).columns\ny = feat_selector.ranking_\ndf = pd.DataFrame({'feature':x, 'rank':y})\n\ndf = df.sort_values(by=['rank'], ascending=True)\n\ndf\n"

# %%
# calculer les corrélations entre features
corr = sk_id_focus_credit_balance.corr(method='pearson')
corr = pd.melt(corr.reset_index(), id_vars='index')
corr.columns = ['x', 'y', 'value']
# visualiser les corrélations entre features
heatmap(
    x=corr['x'],
    y=corr['y'],
    size=corr['value'].abs(),
    color=corr['value']
)

# %% [markdown]
# ## Aggregate over Card balance

# %%
# third level
card_balance = pd.read_csv('Data/credit_card_balance.csv')

# %%
# same with card_balance
card_balance.fillna(0, inplace=True)
focus_card_balance = card_balance[card_balance['NAME_CONTRACT_STATUS'] == 'Active']

# %%
# filtering effect
card_dpd_count = focus_card_balance[focus_card_balance['SK_DPD'] != 0].shape[0]
card_dpd_def_count = focus_card_balance[focus_card_balance['SK_DPD_DEF'] != 0].shape[0]
print('dpd_def tolerance filtering ratio: ',
      round(100 * (card_dpd_def_count/card_dpd_count), 2))
# Out:
# dpd_def tolerance filtering ratio:  57.89

# %% [markdown]
# Tolerance level seems higher for credit card overdue.

# %%
# get loan age - in months and term for each previous loan
focus_card_balance_agg = focus_card_balance.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'MONTHS_BALANCE': ['min', 'size']})
focus_card_balance_agg.columns = [
    'SK_ID_PREV',
    'CC_N_PREV_LOAN_AGE_MONTH',
    'CC_N_PREV_LOAN_TERM']
focus_card_balance.drop(columns=['NAME_CONTRACT_STATUS'], inplace=True)

# %%
# to get earliness of DPD overdue we need to catch min of CNT_INSTALMENT with SK_DPD > 0
dpd_card_balance = focus_card_balance[focus_card_balance['SK_DPD'] != 0]
dpd_card_balance_agg = dpd_card_balance.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'MONTHS_BALANCE': ['min']})
dpd_card_balance_agg.columns = [
    'SK_ID_PREV',
    'CC_N_DPD_PREV_EARLIER_OVERDUE']

# %%
# to get earliness of DPD_DEF overdue we need to catch min of CNT_INSTALMENT with SK_DPD_DEF > 0
dpd_def_card_balance = focus_card_balance[focus_card_balance['SK_DPD_DEF'] != 0]
dpd_def_card_balance_agg = dpd_def_card_balance.groupby(
    'SK_ID_PREV',
    as_index=False).agg(
    {'MONTHS_BALANCE': ['min']})
dpd_def_card_balance_agg.columns = [
    'SK_ID_PREV',
    'CC_N_DPD_DEF_PREV_EARLIER_OVERDUE']

# %%
# merge with raw earlier overdue
card_balance_agg = focus_card_balance_agg.merge(dpd_card_balance_agg, how='left', on='SK_ID_PREV')
card_balance_agg = card_balance_agg.merge(dpd_def_card_balance_agg, how='left', on='SK_ID_PREV')

# %%
del dpd_card_balance_agg
del dpd_def_card_balance_agg

# %%
# manual FE
card_balance_agg['CC_N_DPD_PREV_EARLINESS_OVERDUE_RATIO'] = 1 + card_balance_agg['CC_N_DPD_PREV_EARLIER_OVERDUE'] / card_balance_agg['CC_N_PREV_LOAN_TERM']
card_balance_agg.drop(columns=['CC_N_DPD_PREV_EARLIER_OVERDUE'], inplace=True)
card_balance_agg['CC_N_DPD_PREV_EARLINESS_OVERDUE_RATIO'].fillna(0, inplace=True)
card_balance_agg['CC_N_DPD_PREV_EARLINESS_OVERDUE_RATIO'] = card_balance_agg['CC_N_DPD_PREV_EARLINESS_OVERDUE_RATIO'].apply(lambda x: x if x > 0 else 0)
card_balance_agg['CC_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO'] = 1 + card_balance_agg['CC_N_DPD_DEF_PREV_EARLIER_OVERDUE'] / card_balance_agg['CC_N_PREV_LOAN_TERM']
card_balance_agg.drop(columns=['CC_N_DPD_DEF_PREV_EARLIER_OVERDUE'], inplace=True)
card_balance_agg['CC_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO'].fillna(0, inplace=True)
card_balance_agg['CC_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO'] = card_balance_agg['CC_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO'].apply(lambda x: x if x > 0 else 0)
card_balance_agg['CC_N_PREV_LOAN_AGE'] = - card_balance_agg['CC_N_PREV_LOAN_AGE_MONTH'] / 12

# %% [markdown]
# card_balance_agg will be merged later on SK_ID_PREV

# %%
# Preprocess credit_card_balance.csv
def credit_card_balance(cc, num_rows = None, nan_as_category = True):
    # General aggregations
    cc.drop(['SK_ID_PREV'], axis= 1, inplace = True)
    cc_agg = cc.groupby('SK_ID_CURR').agg(['min', 'max', 'mean', 'sum', 'var'])
    cc_agg.columns = pd.Index(['CC_' + e[0] + "_" + e[1].upper() for e in cc_agg.columns.tolist()])
    # Count credit card lines
    cc_agg['N_CC_COUNT'] = cc.groupby('SK_ID_CURR').size()
    return cc_agg

# %%
# Preprocess credit_card_balance.csv
sk_id_card_balance = credit_card_balance(card_balance, num_rows=None)

# %%
# get late use by applicant of any credit card (max of drawing amount / credit_limit)
last_month = -6
late_card_use = card_balance[card_balance['MONTHS_BALANCE'] >= last_month]
late_card_use = late_card_use[late_card_use['AMT_CREDIT_LIMIT_ACTUAL'] > 0]
late_card_use['N_CC_USE'] = late_card_use['AMT_BALANCE'] / late_card_use['AMT_CREDIT_LIMIT_ACTUAL']
late_card_use = late_card_use.groupby(
    'SK_ID_CURR'
)['N_CC_USE'].max().reset_index().rename(
    columns={'N_CC_USE': 'N_CC_USE_LATE_MONTH_'+str(last_month*-1)})

# %%
# merge with late_card_use
sk_id_card_balance = sk_id_card_balance.merge(late_card_use, how='left', on='SK_ID_CURR')
sk_id_card_balance['N_CC_USE_LATE_MONTH_6'].fillna(0, inplace=True)

# %%
# get late use by applicant of any credit card (max of drawing amount / credit_limit)
last_month = -2
late_card_use = card_balance[card_balance['MONTHS_BALANCE'] >= last_month]
late_card_use = late_card_use[late_card_use['AMT_CREDIT_LIMIT_ACTUAL'] > 0]
late_card_use['N_CC_USE'] = late_card_use['AMT_BALANCE'] / late_card_use['AMT_CREDIT_LIMIT_ACTUAL']
late_card_use = late_card_use.groupby(
    'SK_ID_CURR'
)['N_CC_USE'].max().reset_index().rename(
    columns={'N_CC_USE': 'N_CC_USE_LATE_MONTH_'+str(last_month*-1)})
sk_id_card_balance = sk_id_card_balance.merge(late_card_use, how='left', on='SK_ID_CURR')
sk_id_card_balance['N_CC_USE_LATE_MONTH_2'].fillna(0, inplace=True)

# %%
del late_card_use

# %%
del card_balance

# %%
# merge to target for corr study
cc_target = target.merge(sk_id_card_balance, how='left', on='SK_ID_CURR')
cc_corrs = target_corrs(cc_target)
cc_corrs.head(10)
# Out:
#                               feature  abs_corr
# 103             N_CC_USE_LATE_MONTH_2  0.146758
# 102             N_CC_USE_LATE_MONTH_6  0.144609
# 68   CC_CNT_DRAWINGS_ATM_CURRENT_MEAN  0.117815
# 72        CC_CNT_DRAWINGS_CURRENT_MAX  0.101389
# 67    CC_CNT_DRAWINGS_ATM_CURRENT_MAX  0.087636
# 8                 CC_AMT_BALANCE_MEAN  0.087177
# 63       CC_AMT_TOTAL_RECEIVABLE_MEAN  0.086490
# 58              CC_AMT_RECIVABLE_MEAN  0.086478
# 53   CC_AMT_RECEIVABLE_PRINCIPAL_MEAN  0.086062
# 73       CC_CNT_DRAWINGS_CURRENT_MEAN  0.082520

# %%
# most interesting feature study through plot
kde_plot(cc_target, 'N_CC_USE_LATE_MONTH_2')

# %%
cc_target.isna().sum().head(3)
# Out:
# SK_ID_CURR                    0
# TARGET                        0
# CC_MONTHS_BALANCE_MIN    220606
# dtype: int64

# %% [markdown]
# Those cc aggregative data produce missing values once merged with SK_ID, meaning we have no previous internal knowledge about those clients before application according to credit card details.
# N_CC_COUNT is therefore zero for those 220606 SK_ID.

# %% [markdown]
# ## Aggregate "over" Previous credits

# %% [markdown]
# There are many inconsistencies between the previous loans and the 3 sources of balance / installments details.

# %%
credit_balance_agg.columns
# Out:
# Index(['SK_ID_PREV', 'POS_N_PREV_LOAN_AGE_MONTH', 'POS_N_PREV_LOAN_TERM',
#        'POS_N_DPD_PREV_EARLINESS_OVERDUE_RATIO',
#        'POS_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO', 'POS_N_PREV_LOAN_AGE'],
#       dtype='object')

# %%
card_balance_agg.columns
# Out:
# Index(['SK_ID_PREV', 'CC_N_PREV_LOAN_AGE_MONTH', 'CC_N_PREV_LOAN_TERM',
#        'CC_N_DPD_PREV_EARLINESS_OVERDUE_RATIO',
#        'CC_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO', 'CC_N_PREV_LOAN_AGE'],
#       dtype='object')

# %%
# prepare concatenation
credit_balance_agg = credit_balance_agg.rename(
    columns={
        'POS_N_PREV_LOAN_TERM': 'NC_LOAN_TERM',
        'POS_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO': 'NC_EARLINESS_OVERDUE_RATIO',
        'POS_N_DPD_PREV_EARLINESS_OVERDUE_RATIO': 'NC_EARLINESS_OVERDUE_RATIO_DEF',
        'POS_N_PREV_LOAN_AGE': 'NC_LOAN_AGE'})
credit_balance_agg.drop(
    ['POS_N_PREV_LOAN_AGE_MONTH'],
    axis= 1,
    inplace = True)
credit_balance_agg.columns
# Out:
# Index(['SK_ID_PREV', 'NC_LOAN_TERM', 'NC_EARLINESS_OVERDUE_RATIO_DEF',
#        'NC_EARLINESS_OVERDUE_RATIO', 'NC_LOAN_AGE'],
#       dtype='object')

# %%
# prepare concatenation
card_balance_agg = card_balance_agg.rename(
    columns={
        'CC_N_PREV_LOAN_TERM': 'NC_LOAN_TERM',
        'CC_N_DPD_PREV_EARLINESS_OVERDUE_RATIO': 'NC_EARLINESS_OVERDUE_RATIO',
        'CC_N_DPD_DEF_PREV_EARLINESS_OVERDUE_RATIO': 'NC_EARLINESS_OVERDUE_RATIO_DEF',
        'CC_N_PREV_LOAN_AGE': 'NC_LOAN_AGE'})
card_balance_agg.drop(
    ['CC_N_PREV_LOAN_AGE_MONTH'],
    axis= 1,
    inplace = True)
card_balance_agg.columns
# Out:
# Index(['SK_ID_PREV', 'NC_LOAN_TERM', 'NC_EARLINESS_OVERDUE_RATIO',
#        'NC_EARLINESS_OVERDUE_RATIO_DEF', 'NC_LOAN_AGE'],
#       dtype='object')

# %%
# perform concat
balance_agg = pd.concat([card_balance_agg, credit_balance_agg])

# %%
del card_balance_agg
del credit_balance_agg

# %%
# clean features
balance_agg['NC_EARLINESS_OVERDUE_RATIO'] = balance_agg['NC_EARLINESS_OVERDUE_RATIO'].apply(lambda x: x if x > 0 else 0)
balance_agg['NC_EARLINESS_OVERDUE_RATIO_DEF'] = balance_agg['NC_EARLINESS_OVERDUE_RATIO_DEF'].apply(lambda x: x if x > 0 else 0)

# %%
# load previous
with open("Data/previous.pkl", mode="rb") as df:
    previous = pickle.load(df)

# %%
# merge balance_agg of loans data as a first aggregation step
previous = previous.merge(balance_agg, how='left', on='SK_ID_PREV')

# %%
del balance_agg

# %%
# manual FE
previous['DAYS_DUE_GAP'] = previous['DAYS_FIRST_DUE'] - previous['DAYS_LAST_DUE_1ST_VERSION']
previous['AMT_CREDIT'].replace(0, np.nan, inplace=True)
previous['AMT_APPLICATION'].replace(0, np.nan, inplace=True)
previous['AMT_GOODS_PRICE'].replace(0, np.nan, inplace=True)
# Days 365.243 values -> nan
previous['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
previous['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
previous['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
previous['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
previous['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
# Add feature: value ask / value received percentage
previous['N_APP_CREDIT_RATIO'] = previous['AMT_APPLICATION'] / previous['AMT_CREDIT']
previous['N_ADJ_CREDIT_RATIO'] = (previous['AMT_APPLICATION'] - previous['AMT_CREDIT']) / previous['AMT_APPLICATION']
previous['N_ADJ_INTEREST_EVAL'] = (previous['AMT_CREDIT'] -  previous['AMT_GOODS_PRICE']) / previous['AMT_GOODS_PRICE']
previous['N_CREDIT_PROLONG_RATIO'] = (previous['DAYS_LAST_DUE'] - previous['DAYS_LAST_DUE_1ST_VERSION']) / (previous['DAYS_DUE_GAP'] - 1)

# %%
# Preprocess previous_applications.csv
def previous_applications(prev, num_rows = None, nan_as_category = True):
    prev, cat_cols = one_hot_encoder(prev, nan_as_category= True)
    # Previous applications numeric features
    num_aggregations = {
        'AMT_ANNUITY': ['min', 'max', 'mean'],
        'AMT_APPLICATION': ['min', 'max', 'mean'],
        'AMT_CREDIT': ['min', 'max', 'mean'],
        'N_APP_CREDIT_RATIO': ['min', 'max', 'mean', 'var'],
        'N_ADJ_CREDIT_RATIO': ['min', 'max', 'mean', 'var'],
        'N_ADJ_INTEREST_EVAL': ['min', 'max', 'mean', 'var'],
        'N_CREDIT_PROLONG_RATIO': ['min', 'max', 'mean', 'var'],
        'AMT_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'AMT_GOODS_PRICE': ['min', 'max', 'mean'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum', 'var'],
        'NC_LOAN_TERM': ['min', 'max', 'mean', 'sum', 'var'],
        'NC_EARLINESS_OVERDUE_RATIO': ['min', 'max', 'mean', 'sum', 'var'],
        'NC_EARLINESS_OVERDUE_RATIO_DEF': ['min', 'max', 'mean', 'sum', 'var'],
        'NC_LOAN_AGE': ['min', 'max', 'mean', 'sum', 'var'],
        'NFLAG_INSURED_ON_APPROVAL': ['sum', 'mean']
    }
    # Previous applications categorical features
    cat_aggregations = {}
    for cat in cat_cols:
        cat_aggregations[cat] = ['mean']
    
    prev_agg = prev.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    prev_agg.columns = pd.Index(['PREV_' + e[0] + "_" + e[1].upper() for e in prev_agg.columns.tolist()])
    # Previous Applications: Approved Applications - only numerical features
    approved = prev[prev['NAME_CONTRACT_STATUS_Approved'] == 1]
    approved_agg = approved.groupby('SK_ID_CURR').agg(num_aggregations)
    approved_agg.columns = pd.Index(['APPROVED_' + e[0] + "_" + e[1].upper() for e in approved_agg.columns.tolist()])
    prev_agg = prev_agg.join(approved_agg, how='left', on='SK_ID_CURR')
    # Previous Applications: Refused Applications - only numerical features
    refused = prev[prev['NAME_CONTRACT_STATUS_Refused'] == 1]
    refused_agg = refused.groupby('SK_ID_CURR').agg(num_aggregations)
    refused_agg.columns = pd.Index(['REFUSED_' + e[0] + "_" + e[1].upper() for e in refused_agg.columns.tolist()])
    prev_agg = prev_agg.join(refused_agg, how='left', on='SK_ID_CURR')
    return prev_agg

# %%
# Preprocess previous_applications.csv
sk_id_previous = previous_applications(previous, num_rows=None)

# %%
del previous

# %%
# check for missing values
missing_values = missing_values_table(sk_id_previous)
# get the missing curve
missing_list = []
for i in np.arange(0, 101, 1):
    missing = sk_id_previous.shape[1] - len(list(missing_values.index[missing_values['% of Total Values'] > i]))
    missing_list.append(missing)
pd.DataFrame(missing_list).plot()
# Out:
# Your selected dataframe has 338 columns.
# There are 177 columns that have missing values.
# <AxesSubplot:>

# %%
def remove_missing_col(df, threshold=90):
    miss_data = pd.DataFrame((df.isnull().sum()) * 100 / df.shape[0])
    miss_data_col = miss_data[miss_data[0] > threshold].index
    data_new = df[[i for i in df.columns if i not in miss_data_col]]
    return data_new

# %%
sk_id_previous_clean = remove_missing_col(sk_id_previous)

# %% [markdown]
# ## Aggregate over Bureau & Bureau_balance

# %% [markdown]
# We compute info from bureau_balance

# %%
# load previous
with open("Data/bureau.pkl", mode="rb") as df:
    bureau = pickle.load(df)

# %%
# third level
bureau_balance = pd.read_csv('Data/bureau_balance.csv')

# %%
# to get earliness of overdue we need to catch min of MONTHS_BALANCE out of !=C, X, or 0 STATUS
focus_bureau_balance = bureau_balance[bureau_balance['STATUS'] != 'C']
focus_bureau_balance = focus_bureau_balance[focus_bureau_balance['STATUS'] != 'X']
focus_bureau_balance = focus_bureau_balance[focus_bureau_balance['STATUS'] != '0']
focus_bureau_balance_agg = focus_bureau_balance.groupby(
    'SK_ID_BUREAU',
    as_index=False).agg(
    {'MONTHS_BALANCE': ['min']})
focus_bureau_balance_agg.columns = [
    'SK_ID_BUREAU',
    'N_BUR_EARLIER_OVERDUE']
bureau = bureau.merge(focus_bureau_balance_agg, how='left', on='SK_ID_BUREAU')

# %%
# get credit AGE in months since closure
closing_bureau_balance = bureau_balance[bureau_balance['STATUS'] == 'C']
closing_bureau_balance_agg = closing_bureau_balance.groupby(
    'SK_ID_BUREAU',
    as_index=False).agg(
    {'STATUS': ['count']})
closing_bureau_balance_agg.columns = [
    'SK_ID_BUREAU',
    'N_CREDIT_CLOSING_MONTHS']
bureau = bureau.merge(closing_bureau_balance_agg, how='left', on='SK_ID_BUREAU')

# %%
del closing_bureau_balance_agg

# %%
# to get duration of bureau credit 
term_bureau_balance = bureau_balance[bureau_balance['STATUS'] != 'C']
term_bureau_balance = term_bureau_balance[term_bureau_balance['STATUS'] != 'X']
term_bureau_balance_agg = term_bureau_balance.groupby(
    'SK_ID_BUREAU',
    as_index=False).agg(
    {'MONTHS_BALANCE': ['min']})
term_bureau_balance_agg.columns = [
    'SK_ID_BUREAU',
    'N_BUR_START_OBSERVED']
bureau = bureau.merge(term_bureau_balance_agg, how='left', on='SK_ID_BUREAU')

# %%
del term_bureau_balance_agg

# %%
# about earlier overdue
bureau['N_BUR_EARLINESS_OVERDUE_RATIO'] = bureau['N_BUR_EARLIER_OVERDUE'] / bureau['N_BUR_START_OBSERVED']
bureau.drop(columns=['N_BUR_EARLIER_OVERDUE'], inplace=True)
bureau['N_BUR_EARLINESS_OVERDUE_RATIO'].fillna(0, inplace=True)
bureau['N_BUR_AMT_CREDIT_DEBT_RATE'] = bureau['AMT_CREDIT_SUM_DEBT'] / (1 + bureau['AMT_CREDIT_SUM'])

# %%
# Preprocess bureau.csv and bureau_balance.csv
def bureau_and_balance(bureau, bb, num_rows = None, nan_as_category = True):
    bb, bb_cat = one_hot_encoder(bb, nan_as_category)
    bureau, bureau_cat = one_hot_encoder(bureau, nan_as_category) 
    # Bureau balance: Perform aggregations and merge with bureau.csv
    bb_aggregations = {'MONTHS_BALANCE': ['min', 'max', 'size']}
    for col in bb_cat:
        bb_aggregations[col] = ['mean']
    print(bb_aggregations)
    bb_agg = bb.groupby('SK_ID_BUREAU').agg(bb_aggregations)
    bb_agg.columns = pd.Index([e[0] + "_" + e[1].upper() for e in bb_agg.columns.tolist()])
    bureau = bureau.join(bb_agg, how='left', on='SK_ID_BUREAU')
    bureau.drop(['SK_ID_BUREAU'], axis=1, inplace= True)
    # Bureau and bureau_balance numeric features
    num_aggregations = {
        'DAYS_CREDIT': ['min', 'max', 'mean', 'var'],
        'DAYS_CREDIT_ENDDATE': ['min', 'max', 'mean'],
        'CREDIT_DAY_OVERDUE': ['max', 'mean'],
        'AMT_CREDIT_MAX_OVERDUE': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_DEBT': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_OVERDUE': ['max', 'mean', 'sum'],
        'AMT_CREDIT_SUM_LIMIT': ['max', 'mean', 'sum'],
        'AMT_ANNUITY':  ['max', 'mean', 'sum'],
        'CNT_CREDIT_PROLONG': ['sum'],
        'MONTHS_BALANCE_MIN': ['min'],
        'MONTHS_BALANCE_MAX': ['max'],
        'MONTHS_BALANCE_SIZE': ['mean', 'sum'],
        'N_CREDIT_CLOSING_MONTHS': ['max', 'mean'],
        'N_BUR_START_OBSERVED' : ['min', 'max', 'mean', 'sum', 'var'],
        'N_BUR_EARLINESS_OVERDUE_RATIO': ['min', 'max', 'mean', 'sum', 'var'],
        'N_BUR_AMT_CREDIT_DEBT_RATE': ['min', 'max', 'mean', 'sum', 'var']       
    }
    # Bureau and bureau_balance categorical features
    cat_aggregations = {}
    for cat in bureau_cat: cat_aggregations[cat] = ['mean']
    for cat in bb_cat: cat_aggregations[cat + "_MEAN"] = ['mean']
    bureau_agg = bureau.groupby('SK_ID_CURR').agg({**num_aggregations, **cat_aggregations})
    bureau_agg.columns = pd.Index(['BUR_' + e[0] + "_" + e[1].upper() for e in bureau_agg.columns.tolist()])
    # Bureau: Active credits - using only numerical aggregations
    active = bureau[bureau['CREDIT_ACTIVE_Active'] == 1]
    active_agg = active.groupby('SK_ID_CURR').agg(num_aggregations)
    active_agg.columns = pd.Index(['ACTIVE_' + e[0] + "_" + e[1].upper() for e in active_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(active_agg, how='left', on='SK_ID_CURR')
    # Bureau: Closed credits - using only numerical aggregations
    closed = bureau[bureau['CREDIT_ACTIVE_Closed'] == 1]
    closed_agg = closed.groupby('SK_ID_CURR').agg(num_aggregations)
    closed_agg.columns = pd.Index(['CLOSED_' + e[0] + "_" + e[1].upper() for e in closed_agg.columns.tolist()])
    bureau_agg = bureau_agg.join(closed_agg, how='left', on='SK_ID_CURR')
    return bureau_agg

# %%
# Preprocess bureau.csv and bureau_balance.csv
sk_id_bureau = bureau_and_balance(bureau, bureau_balance, num_rows=None)
# Out:
# {'MONTHS_BALANCE': ['min', 'max', 'size'], 'STATUS_0': ['mean'], 'STATUS_1': ['mean'], 'STATUS_2': ['mean'], 'STATUS_3': ['mean'], 'STATUS_4': ['mean'], 'STATUS_5': ['mean'], 'STATUS_C': ['mean'], 'STATUS_X': ['mean'], 'STATUS_nan': ['mean']}

# %%
del bureau
del bureau_balance

# %%
# check for missing values
missing_values = missing_values_table(sk_id_bureau)
# get the missing curve
missing_list = []
for i in np.arange(0, 101, 1):
    missing = sk_id_bureau.shape[1] - len(list(missing_values.index[missing_values['% of Total Values'] > i]))
    missing_list.append(missing)
pd.DataFrame(missing_list).plot()
# Out:
# Your selected dataframe has 169 columns.
# There are 135 columns that have missing values.
# <AxesSubplot:>

# %% [markdown]
# ## Treat Applications
# We proceed with manual FE on any applicant's profile

# %%
with open("Data/any_app.pkl", mode="rb") as df:
    any_applications = pickle.load(df)

# %%
# Preprocess application_train.csv and application_test.csv
def application_train_test(df, num_rows=None, nan_as_category=False): 
    # Categorical features with Binary encode (0 or 1; two categories)
    df = label_encoder(df)
    # Categorical features with One-Hot encode
    df, cat_cols = one_hot_encoder(df, nan_as_category)
    return df, cat_cols

# %%
# Preprocess application_train.csv and application_test.csv
application, catApp = application_train_test(any_applications, num_rows=None)
# Out:
# 4 columns were label encoded. ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY']

# %%
del any_applications

# %%
# merge to target for corr study
app_target = application[application['TARGET'].notna()]
app_target_corrs = target_corrs(app_target)

# %%
app_target_corrs.head(10)
# Out:
#                          feature  abs_corr
# 33                  EXT_SOURCE_3  0.178926
# 32                  EXT_SOURCE_2  0.160471
# 31                  EXT_SOURCE_1  0.155317
# 123                N_REJECT_RATE  0.078596
# 127                  YEARS_BIRTH  0.078242
# 11                 DAYS_EMPLOYED  0.074957
# 128        N_DAYS_EMPLOYED_RATIO  0.067952
# 120           N_ADJ_REJECT_INDEX  0.064858
# 118              N_FLAG_REJECTED  0.063833
# 23   REGION_RATING_CLIENT_W_CITY  0.060895

# %%
# most interesting feature study through plot
kde_plot(app_target, 'N_REJECT_RATE')

# %%
# check for missing values
missing_values = missing_values_table(application)
# get the missing curve
missing_list = []
for i in np.arange(0, 101, 1):
    missing = application.shape[1] - len(list(missing_values.index[missing_values['% of Total Values'] > i]))
    missing_list.append(missing)
pd.DataFrame(missing_list).plot()
# Out:
# Your selected dataframe has 277 columns.
# There are 61 columns that have missing values.
# <AxesSubplot:>

# %% [markdown]
# # Merge any applicant's knowledge

# %% [markdown]
# ## Optimize df size

# %%
'''
print('application :')
application = convert_types(application, print_info=True)
print('sk_id_bureau :')
sk_id_bureau = convert_types(sk_id_bureau, print_info=True)
print('sk_id_previous_clean :')
sk_id_previous_clean = convert_types(sk_id_previous_clean, print_info=True)
print('sk_id_focus_credit_balance :')
sk_id_focus_credit_balance = convert_types(sk_id_focus_credit_balance, print_info=True)
print('sk_id_card_balance :')
sk_id_card_balance = convert_types(sk_id_card_balance, print_info=True)
print('sk_id_installments :')
sk_id_installments = convert_types(sk_id_installments, print_info=True)
print('sk_id_installments_agg :')
sk_id_installments_agg = convert_types(sk_id_installments_agg, print_info=True)
'''

# %% [markdown]
# ## Merge data & save

# %%
print("initial shape:", application.shape)
application = application.merge(sk_id_bureau, how='left', on='SK_ID_CURR')
print("with sk_id_bureau:", application.shape)
# Out:
# initial shape: (356251, 277)
# with sk_id_bureau: (356251, 446)

# %%
del sk_id_bureau

# %%
application = application.merge(sk_id_previous_clean, how='left', on='SK_ID_CURR')
print("with sk_id_previous_clean:", application.shape)
# Out:
# with sk_id_previous_clean: (356251, 763)

# %%
del sk_id_previous_clean

# %%
application = application.merge(sk_id_installments_agg, how='left', on='SK_ID_CURR')
print("with sk_id_installments_agg agg", application.shape)
# Out:
# with sk_id_installments_agg agg (356251, 793)

# %%
del sk_id_installments_agg

# %%
application = application.merge(sk_id_installments, how='left', on='SK_ID_CURR')
print("with installments agg", application.shape)
# Out:
# with installments agg (356251, 811)

# %%
del sk_id_installments

# %%
application = application.merge(sk_id_focus_credit_balance, how='left', on='SK_ID_CURR')
print("with credit balance agg", application.shape)
# Out:
# with credit balance agg (356251, 820)

# %%
del sk_id_focus_credit_balance

# %%
application = application.merge(sk_id_card_balance, how='left', on='SK_ID_CURR')
print("with card balance agg", application.shape)
# Out:
# with card balance agg (356251, 923)

# %%
del sk_id_card_balance

# %%
columns = application.columns.tolist()
key = 'SK_ID'
cols_with_sk_id = [item for item in columns if key in item]
print(cols_with_sk_id)
# Out:
# ['SK_ID_CURR']

# %% [markdown]
# ## Examine Missing Values
#
# Next we can look at the number and percentage of missing values in each column.

# %%
# check for missing values
missing_values = missing_values_table(application)
# Out:
# Your selected dataframe has 923 columns.
# There are 707 columns that have missing values.

# %%
missing_values
# Out:
#                                      Missing Values  % of Total Values
# ACTIVE_N_CREDIT_CLOSING_MONTHS_MAX           320144               89.9
# ACTIVE_N_CREDIT_CLOSING_MONTHS_MEAN          320144               89.9
# REFUSED_AMT_DOWN_PAYMENT_MIN                 303649               85.2
# REFUSED_RATE_DOWN_PAYMENT_MEAN               303649               85.2
# REFUSED_RATE_DOWN_PAYMENT_MAX                303649               85.2
# ...                                             ...                ...
# N_CREDIT_TERM                                    36                0.0
# N_ANNUITY_INCOME_RATIO                           36                0.0
# N_INCOME_PER_PERSON                               2                0.0
# CNT_FAM_MEMBERS                                   2                0.0
# DAYS_LAST_PHONE_CHANGE                            1                0.0
#
# [707 rows x 2 columns]

# %%
# get the missing curve
missing_list = []
for i in np.arange(0, 101, 1):
    missing = application.shape[1] - len(list(missing_values.index[missing_values['% of Total Values'] > i]))
    missing_list.append(missing)
pd.DataFrame(missing_list).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# A first set of features can be safely removed and is the result of wrong aggregation method during "automated" FE.

# %%
# get the list of features to remove
remove_missing = list(missing_values.index[missing_values['% of Total Values'] > 85])

# %%
remove_missing
# Out:
# ['ACTIVE_N_CREDIT_CLOSING_MONTHS_MAX',
#  'ACTIVE_N_CREDIT_CLOSING_MONTHS_MEAN',
#  'REFUSED_AMT_DOWN_PAYMENT_MIN',
#  'REFUSED_RATE_DOWN_PAYMENT_MEAN',
#  'REFUSED_RATE_DOWN_PAYMENT_MAX',
#  'REFUSED_RATE_DOWN_PAYMENT_MIN',
#  'REFUSED_AMT_DOWN_PAYMENT_MEAN',
#  'REFUSED_AMT_DOWN_PAYMENT_MAX']

# %%
application.drop(columns=remove_missing, inplace=True)

# %%
with open("Data/application.pkl", mode="wb") as df:
    pickle.dump(application, df)

# %% [markdown]
# # Global feature selection

# %% [markdown]
# ## "Model agnostic" Boruta Feature Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from boruta import BorutaPy

# %%
# keep training applications only
train = application[application['TARGET'].notna()]

# %%
# set index with SK_ID_CURR
train = train.set_index('SK_ID_CURR')

# %%
X_ = train.drop(columns=['TARGET'])
y_ = train['TARGET']

# %%
X_sample, _, y_sample, _ = train_test_split(
        X_,
        y_,
        stratify=y_,
        test_size=0.8,
        random_state=42)

# %%
imputer = SimpleImputer(
    missing_values=np.nan,
    strategy='mean')
imputer.fit(X_sample)
X_sample = imputer.transform(X_sample)

# %%
# define random forest classifier, with utilising all cores and
# sampling in proportion to y labels
rf = RandomForestClassifier(n_jobs=-1, class_weight='balanced', max_depth=6)

# %%
# define Boruta feature selection method
feat_selector = BorutaPy(rf, n_estimators='auto', max_iter=15, verbose=2, random_state=1)

# %%
# find all relevant features - features should be selected
feat_selector.fit(X_sample, y_sample)
# Out:
# Iteration: 	1 / 15
# Confirmed: 	0
# Tentative: 	913
# Rejected: 	0
# Iteration: 	2 / 15
# Confirmed: 	0
# Tentative: 	913
# Rejected: 	0
# Iteration: 	3 / 15
# Confirmed: 	0
# Tentative: 	913
# Rejected: 	0
# Iteration: 	4 / 15
# Confirmed: 	0
# Tentative: 	913
# Rejected: 	0
# Iteration: 	5 / 15
# Confirmed: 	0
# Tentative: 	913
# Rejected: 	0
# Iteration: 	6 / 15
# Confirmed: 	0
# Tentative: 	913
# Rejected: 	0
# Iteration: 	7 / 15
# Confirmed: 	0
# Tentative: 	913
# Rejected: 	0
# Iteration: 	8 / 15
# Confirmed: 	248
# Tentative: 	125
# Rejected: 	540
# Iteration: 	9 / 15
# Confirmed: 	248
# Tentative: 	125
# Rejected: 	540
# Iteration: 	10 / 15
# Confirmed: 	248
# Tentative: 	125
# Rejected: 	540
# Iteration: 	11 / 15
# Confirmed: 	248
# Tentative: 	125
# Rejected: 	540
# Iteration: 	12 / 15
# Confirmed: 	251
# Tentative: 	90
# Rejected: 	572
# Iteration: 	13 / 15
# Confirmed: 	251
# Tentative: 	90
# Rejected: 	572
# Iteration: 	14 / 15
# Confirmed: 	251
# Tentative: 	90
# Rejected: 	572
#
#
# BorutaPy finished running.
#
# Iteration: 	15 / 15
# Confirmed: 	251
# Tentative: 	38
# Rejected: 	572
# BorutaPy(estimator=RandomForestClassifier(class_weight='balanced', max_depth=6,
#                                           n_estimators=435, n_jobs=-1,
#                                           random_state=RandomState(MT19937) at 0x1410C2CF598),
#          max_iter=15, n_estimators='auto',
#          random_state=RandomState(MT19937) at 0x1410C2CF598, verbose=2)

# %%
pd.options.display.max_rows = 999

# %%
x = train.drop(columns=['TARGET']).columns
y = feat_selector.ranking_
df = pd.DataFrame({'feature': x, 'rank': y})
df = df.sort_values(by=['rank'], ascending=True)
df
# Out:
#                                                feature  rank
# 456                        PREV_N_ADJ_CREDIT_RATIO_MAX     1
# 459                       PREV_N_ADJ_INTEREST_EVAL_MIN     1
# 457                       PREV_N_ADJ_CREDIT_RATIO_MEAN     1
# 911                              N_CC_USE_LATE_MONTH_6     1
# 455                        PREV_N_ADJ_CREDIT_RATIO_MIN     1
# 453                       PREV_N_APP_CREDIT_RATIO_MEAN     1
# 452                        PREV_N_APP_CREDIT_RATIO_MAX     1
# 451                        PREV_N_APP_CREDIT_RATIO_MIN     1
# 450                               PREV_AMT_CREDIT_MEAN     1
# 449                                PREV_AMT_CREDIT_MAX     1
# 448                                PREV_AMT_CREDIT_MIN     1
# 447                          PREV_AMT_APPLICATION_MEAN     1
# 446                           PREV_AMT_APPLICATION_MAX     1
# 445                           PREV_AMT_APPLICATION_MIN     1
# 444                              PREV_AMT_ANNUITY_MEAN     1
# 443                               PREV_AMT_ANNUITY_MAX     1
# 442                               PREV_AMT_ANNUITY_MIN     1
# 440              CLOSED_N_BUR_AMT_CREDIT_DEBT_RATE_SUM     1
# 436           CLOSED_N_BUR_EARLINESS_OVERDUE_RATIO_VAR     1
# 435           CLOSED_N_BUR_EARLINESS_OVERDUE_RATIO_SUM     1
# 434          CLOSED_N_BUR_EARLINESS_OVERDUE_RATIO_MEAN     1
# 433           CLOSED_N_BUR_EARLINESS_OVERDUE_RATIO_MAX     1
# 460                       PREV_N_ADJ_INTEREST_EVAL_MAX     1
# 461                      PREV_N_ADJ_INTEREST_EVAL_MEAN     1
# 466                    PREV_N_CREDIT_PROLONG_RATIO_VAR     1
# 468                          PREV_AMT_DOWN_PAYMENT_MAX     1
# 619                    PREV_NAME_YIELD_GROUP_high_MEAN     1
# 618                     PREV_NAME_YIELD_GROUP_XNA_MEAN     1
# 608        PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN     1
# 594                PREV_NAME_PRODUCT_TYPE_walk-in_MEAN     1
# 550          PREV_CODE_REJECT_REASON_REJECTED_XAP_MEAN     1
# 547        PREV_CODE_REJECT_REASON_REJECTED_SCOFR_MEAN     1
# 544           PREV_CODE_REJECT_REASON_REJECTED_HC_MEAN     1
# 535             PREV_NAME_CONTRACT_STATUS_Refused_MEAN     1
# 534            PREV_NAME_CONTRACT_STATUS_Approved_MEAN     1
# 501                               PREV_NC_LOAN_AGE_VAR     1
# 432           CLOSED_N_BUR_EARLINESS_OVERDUE_RATIO_MIN     1
# 500                               PREV_NC_LOAN_AGE_SUM     1
# 498                               PREV_NC_LOAN_AGE_MAX     1
# 485                              PREV_NC_LOAN_TERM_SUM     1
# 481                               PREV_CNT_PAYMENT_VAR     1
# 478                            PREV_DAYS_DECISION_MEAN     1
# 477                             PREV_DAYS_DECISION_MAX     1
# 476                             PREV_DAYS_DECISION_MIN     1
# 472                          PREV_AMT_GOODS_PRICE_MEAN     1
# 471                           PREV_AMT_GOODS_PRICE_MAX     1
# 470                           PREV_AMT_GOODS_PRICE_MIN     1
# 469                         PREV_AMT_DOWN_PAYMENT_MEAN     1
# 499                              PREV_NC_LOAN_AGE_MEAN     1
# 620              PREV_NAME_YIELD_GROUP_low_action_MEAN     1
# 419                             CLOSED_AMT_ANNUITY_SUM     1
# 407                          CLOSED_AMT_CREDIT_SUM_SUM     1
# 323                 BUR_N_BUR_AMT_CREDIT_DEBT_RATE_VAR     1
# 322                 BUR_N_BUR_AMT_CREDIT_DEBT_RATE_SUM     1
# 321                BUR_N_BUR_AMT_CREDIT_DEBT_RATE_MEAN     1
# 320                 BUR_N_BUR_AMT_CREDIT_DEBT_RATE_MAX     1
# 311                      BUR_N_BUR_START_OBSERVED_MEAN     1
# 305                       BUR_MONTHS_BALANCE_SIZE_MEAN     1
# 292                        BUR_AMT_CREDIT_SUM_DEBT_SUM     1
# 291                       BUR_AMT_CREDIT_SUM_DEBT_MEAN     1
# 290                        BUR_AMT_CREDIT_SUM_DEBT_MAX     1
# 289                             BUR_AMT_CREDIT_SUM_SUM     1
# 288                            BUR_AMT_CREDIT_SUM_MEAN     1
# 287                             BUR_AMT_CREDIT_SUM_MAX     1
# 286                     BUR_AMT_CREDIT_MAX_OVERDUE_SUM     1
# 285                    BUR_AMT_CREDIT_MAX_OVERDUE_MEAN     1
# 284                     BUR_AMT_CREDIT_MAX_OVERDUE_MAX     1
# 281                       BUR_DAYS_CREDIT_ENDDATE_MEAN     1
# 280                        BUR_DAYS_CREDIT_ENDDATE_MAX     1
# 279                        BUR_DAYS_CREDIT_ENDDATE_MIN     1
# 278                                BUR_DAYS_CREDIT_VAR     1
# 277                               BUR_DAYS_CREDIT_MEAN     1
# 276                                BUR_DAYS_CREDIT_MAX     1
# 324                      BUR_CREDIT_ACTIVE_Active_MEAN     1
# 326                      BUR_CREDIT_ACTIVE_Closed_MEAN     1
# 346                             ACTIVE_DAYS_CREDIT_MIN     1
# 347                             ACTIVE_DAYS_CREDIT_MAX     1
# 406                         CLOSED_AMT_CREDIT_SUM_MEAN     1
# 405                          CLOSED_AMT_CREDIT_SUM_MAX     1
# 404                  CLOSED_AMT_CREDIT_MAX_OVERDUE_SUM     1
# 403                 CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN     1
# 400                      CLOSED_CREDIT_DAY_OVERDUE_MAX     1
# 399                    CLOSED_DAYS_CREDIT_ENDDATE_MEAN     1
# 398                     CLOSED_DAYS_CREDIT_ENDDATE_MAX     1
# 397                     CLOSED_DAYS_CREDIT_ENDDATE_MIN     1
# 395                            CLOSED_DAYS_CREDIT_MEAN     1
# 394                             CLOSED_DAYS_CREDIT_MAX     1
# 412                 CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN     1
# 393                             CLOSED_DAYS_CREDIT_MIN     1
# 390             ACTIVE_N_BUR_AMT_CREDIT_DEBT_RATE_MEAN     1
# 389              ACTIVE_N_BUR_AMT_CREDIT_DEBT_RATE_MAX     1
# 388              ACTIVE_N_BUR_AMT_CREDIT_DEBT_RATE_MIN     1
# 362                    ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN     1
# 359                         ACTIVE_AMT_CREDIT_SUM_MEAN     1
# 357                  ACTIVE_AMT_CREDIT_MAX_OVERDUE_SUM     1
# 355                  ACTIVE_AMT_CREDIT_MAX_OVERDUE_MAX     1
# 351                     ACTIVE_DAYS_CREDIT_ENDDATE_MAX     1
# 349                             ACTIVE_DAYS_CREDIT_VAR     1
# 348                            ACTIVE_DAYS_CREDIT_MEAN     1
# 391              ACTIVE_N_BUR_AMT_CREDIT_DEBT_RATE_SUM     1
# 275                                BUR_DAYS_CREDIT_MIN     1
# 621              PREV_NAME_YIELD_GROUP_low_normal_MEAN     1
# 645               PREV_N_CONTRACT_STATUS_APPROVED_MEAN     1
# 789                                 INS_N_INS_DBD_MEAN     1
# 788                                  INS_N_INS_DPD_VAR     1
# 787                                  INS_N_INS_DPD_SUM     1
# 786                                 INS_N_INS_DPD_MEAN     1
# 785                                  INS_N_INS_DPD_MAX     1
# 783                           INS_DAYS_INSTALMENT_MEAN     1
# 782                     INSAGG_INS_N_PREV_LOAN_AGE_VAR     1
# 781                     INSAGG_INS_N_PREV_LOAN_AGE_SUM     1
# 780                    INSAGG_INS_N_PREV_LOAN_AGE_MEAN     1
# 779                     INSAGG_INS_N_PREV_LOAN_AGE_MAX     1
# 776      INSAGG_INS_N_PREV_EARLINESS_OVERDUE_RATIO_SUM     1
# 775     INSAGG_INS_N_PREV_EARLINESS_OVERDUE_RATIO_MEAN     1
# 774      INSAGG_INS_N_PREV_EARLINESS_OVERDUE_RATIO_MAX     1
# 773      INSAGG_INS_N_PREV_EARLINESS_OVERDUE_RATIO_MIN     1
# 772         INSAGG_INS_N_PREV_LAST_DAYS_INSTALMENT_VAR     1
# 771         INSAGG_INS_N_PREV_LAST_DAYS_INSTALMENT_SUM     1
# 770        INSAGG_INS_N_PREV_LAST_DAYS_INSTALMENT_MEAN     1
# 768         INSAGG_INS_N_PREV_LAST_DAYS_INSTALMENT_MIN     1
# 761          INSAGG_INS_N_PREV_INS_AMT_MAX_OVERDUE_SUM     1
# 760         INSAGG_INS_N_PREV_INS_AMT_MAX_OVERDUE_MEAN     1
# 759          INSAGG_INS_N_PREV_INS_AMT_MAX_OVERDUE_MAX     1
# 790                         INS_N_INS_AMT_OVERDUE_MEAN     1
# 791                        INS_N_AMT_OVERDUE_RATIO_MAX     1
# 792                       INS_N_AMT_OVERDUE_RATIO_MEAN     1
# 793                             INS_AMT_INSTALMENT_MAX     1
# 884                        CC_CNT_DRAWINGS_CURRENT_VAR     1
# 882                       CC_CNT_DRAWINGS_CURRENT_MEAN     1
# 881                        CC_CNT_DRAWINGS_CURRENT_MAX     1
# 879                    CC_CNT_DRAWINGS_ATM_CURRENT_VAR     1
# 877                   CC_CNT_DRAWINGS_ATM_CURRENT_MEAN     1
# 876                    CC_CNT_DRAWINGS_ATM_CURRENT_MAX     1
# 872                       CC_AMT_TOTAL_RECEIVABLE_MEAN     1
# 867                              CC_AMT_RECIVABLE_MEAN     1
# 862                   CC_AMT_RECEIVABLE_PRINCIPAL_MEAN     1
# 832                       CC_AMT_DRAWINGS_CURRENT_MEAN     1
# 758          INSAGG_INS_N_PREV_INS_AMT_MAX_OVERDUE_MIN     1
# 827                   CC_AMT_DRAWINGS_ATM_CURRENT_MEAN     1
# 809                                    POS_N_POS_COUNT     1
# 808                                POS_SK_DPD_DEF_MEAN     1
# 802                            POS_MONTHS_BALANCE_MEAN     1
# 800                               INS_N_FAULT_ADJ_RATE     1
# 799                                INS_N_FAULT_GRAVITY     1
# 798                                   INS_N_FAULT_RATE     1
# 797                                 INS_N_INSTAL_COUNT     1
# 796                                 INS_N_STATUS_0_SUM     1
# 795                             INS_AMT_INSTALMENT_SUM     1
# 794                            INS_AMT_INSTALMENT_MEAN     1
# 817                                CC_AMT_BALANCE_MEAN     1
# 631     PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN     1
# 756                  INSAGG_INS_N_PREV_CNT_PROLONG_SUM     1
# 744                         REFUSED_DAYS_DECISION_MEAN     1
# 680                APPROVED_N_CREDIT_PROLONG_RATIO_VAR     1
# 675                  APPROVED_N_ADJ_INTEREST_EVAL_MEAN     1
# 674                   APPROVED_N_ADJ_INTEREST_EVAL_MAX     1
# 673                   APPROVED_N_ADJ_INTEREST_EVAL_MIN     1
# 671                   APPROVED_N_ADJ_CREDIT_RATIO_MEAN     1
# 670                    APPROVED_N_ADJ_CREDIT_RATIO_MAX     1
# 669                    APPROVED_N_ADJ_CREDIT_RATIO_MIN     1
# 667                   APPROVED_N_APP_CREDIT_RATIO_MEAN     1
# 666                    APPROVED_N_APP_CREDIT_RATIO_MAX     1
# 665                    APPROVED_N_APP_CREDIT_RATIO_MIN     1
# 664                           APPROVED_AMT_CREDIT_MEAN     1
# 663                            APPROVED_AMT_CREDIT_MAX     1
# 662                            APPROVED_AMT_CREDIT_MIN     1
# 661                      APPROVED_AMT_APPLICATION_MEAN     1
# 660                       APPROVED_AMT_APPLICATION_MAX     1
# 659                       APPROVED_AMT_APPLICATION_MIN     1
# 658                          APPROVED_AMT_ANNUITY_MEAN     1
# 657                           APPROVED_AMT_ANNUITY_MAX     1
# 656                           APPROVED_AMT_ANNUITY_MIN     1
# 651         PREV_N_CONTRACT_STATUS_REJECTED_SCOFR_MEAN     1
# 648            PREV_N_CONTRACT_STATUS_REJECTED_HC_MEAN     1
# 682                      APPROVED_AMT_DOWN_PAYMENT_MAX     1
# 683                     APPROVED_AMT_DOWN_PAYMENT_MEAN     1
# 684                       APPROVED_AMT_GOODS_PRICE_MIN     1
# 685                       APPROVED_AMT_GOODS_PRICE_MAX     1
# 743                          REFUSED_DAYS_DECISION_MAX     1
# 742                          REFUSED_DAYS_DECISION_MIN     1
# 739                        REFUSED_AMT_GOODS_PRICE_MIN     1
# 737                   REFUSED_N_ADJ_INTEREST_EVAL_MEAN     1
# 736                    REFUSED_N_ADJ_INTEREST_EVAL_MAX     1
# 733                    REFUSED_N_ADJ_CREDIT_RATIO_MEAN     1
# 731                     REFUSED_N_ADJ_CREDIT_RATIO_MIN     1
# 729                    REFUSED_N_APP_CREDIT_RATIO_MEAN     1
# 728                     REFUSED_N_APP_CREDIT_RATIO_MAX     1
# 727                     REFUSED_N_APP_CREDIT_RATIO_MIN     1
# 746                            REFUSED_CNT_PAYMENT_SUM     1
# 724                             REFUSED_AMT_CREDIT_MIN     1
# 718                            REFUSED_AMT_ANNUITY_MIN     1
# 715                           APPROVED_NC_LOAN_AGE_VAR     1
# 714                           APPROVED_NC_LOAN_AGE_SUM     1
# 713                          APPROVED_NC_LOAN_AGE_MEAN     1
# 712                           APPROVED_NC_LOAN_AGE_MAX     1
# 699                          APPROVED_NC_LOAN_TERM_SUM     1
# 695                           APPROVED_CNT_PAYMENT_VAR     1
# 692                        APPROVED_DAYS_DECISION_MEAN     1
# 690                         APPROVED_DAYS_DECISION_MIN     1
# 686                      APPROVED_AMT_GOODS_PRICE_MEAN     1
# 721                        REFUSED_AMT_APPLICATION_MIN     1
# 247                              ORGANIZATION_TYPE_XNA     1
# 912                              N_CC_USE_LATE_MONTH_2     1
# 30                                        EXT_SOURCE_1     1
# 5                                     AMT_INCOME_TOTAL     1
# 6                                           AMT_CREDIT     1
# 135                         NAME_INCOME_TYPE_Pensioner     1
# 40                                       FLOORSMAX_AVG     1
# 131                                      N_CREDIT_TERM     1
# 7                                          AMT_ANNUITY     1
# 130                             N_ANNUITY_INCOME_RATIO     1
# 52                                      ELEVATORS_MODE     1
# 128                              N_CREDIT_INCOME_RATIO     1
# 8                                      AMT_GOODS_PRICE     1
# 15                                      FLAG_EMP_PHONE     1
# 49                        YEARS_BEGINEXPLUATATION_MODE     1
# 127                              N_DAYS_EMPLOYED_RATIO     1
# 11                                   DAYS_REGISTRATION     1
# 9                           REGION_POPULATION_RELATIVE     1
# 126                                        YEARS_BIRTH     1
# 22                         REGION_RATING_CLIENT_W_CITY     1
# 21                                REGION_RATING_CLIENT     1
# 124                             N_BUR_LAST_APPLICATION     1
# 44                                      LIVINGAREA_AVG     1
# 122                                      N_REJECT_RATE     1
# 113                          N_CNT_PREV_REJECTED_SCOFR     1
# 120                            N_PREV_LAST_APPLICATION     1
# 119                                 N_ADJ_REJECT_INDEX     1
# 117                                    N_FLAG_REJECTED     1
# 118                              N_PREV_LAST_REJECTION     1
# 38                                       ELEVATORS_AVG     1
# 54                                      FLOORSMAX_MODE     1
# 141               NAME_EDUCATION_TYPE_Higher education     1
# 82                                     FLAG_DOCUMENT_3     1
# 75                                      TOTALAREA_MODE     1
# 31                                        EXT_SOURCE_2     1
# 32                                        EXT_SOURCE_3     1
# 28                              REG_CITY_NOT_WORK_CITY     1
# 12                                     DAYS_ID_PUBLISH     1
# 13                                         OWN_CAR_AGE     1
# 68                                      FLOORSMAX_MEDI     1
# 139                           NAME_INCOME_TYPE_Working     1
# 63                        YEARS_BEGINEXPLUATATION_MEDI     1
# 66                                      ELEVATORS_MEDI     1
# 10                                       DAYS_EMPLOYED     1
# 80                              DAYS_LAST_PHONE_CHANGE     1
# 172                          OCCUPATION_TYPE_Pensioner     1
# 144  NAME_EDUCATION_TYPE_Secondary / secondary special     1
# 35                         YEARS_BEGINEXPLUATATION_AVG     1
# 1                                          CODE_GENDER     1
# 834                        CC_AMT_DRAWINGS_CURRENT_VAR     2
# 411                  CLOSED_AMT_CREDIT_SUM_OVERDUE_MAX     2
# 474                         PREV_RATE_DOWN_PAYMENT_MAX     2
# 413                  CLOSED_AMT_CREDIT_SUM_OVERDUE_SUM     2
# 34                                    BASEMENTAREA_AVG     2
# 402                  CLOSED_AMT_CREDIT_MAX_OVERDUE_MAX     2
# 298                       BUR_AMT_CREDIT_SUM_LIMIT_SUM     2
# 831                        CC_AMT_DRAWINGS_CURRENT_MAX     2
# 401                     CLOSED_CREDIT_DAY_OVERDUE_MEAN     2
# 33                                      APARTMENTS_AVG     2
# 416                    CLOSED_AMT_CREDIT_SUM_LIMIT_SUM     2
# 264                      N_PREV_LAST_DECISION_APPROVED     2
# 0                                   NAME_CONTRACT_TYPE     2
# 396                             CLOSED_DAYS_CREDIT_VAR     2
# 541                    PREV_NAME_PAYMENT_TYPE_XNA_MEAN     2
# 553                     PREV_NAME_CLIENT_TYPE_New_MEAN     2
# 479                              PREV_CNT_PAYMENT_MEAN     2
# 61                                     APARTMENTS_MEDI     2
# 883                        CC_CNT_DRAWINGS_CURRENT_SUM     2
# 358                          ACTIVE_AMT_CREDIT_SUM_MAX     2
# 538  PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN     2
# 356                 ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN     2
# 891                    CC_CNT_DRAWINGS_POS_CURRENT_MAX     2
# 352                    ACTIVE_DAYS_CREDIT_ENDDATE_MEAN     2
# 807                                 POS_SK_DPD_DEF_MAX     2
# 643            PREV_N_CREDIT_TYPE_Revolving loans_MEAN     2
# 72                                     LIVINGAREA_MEDI     2
# 688                     APPROVED_RATE_DOWN_PAYMENT_MAX     2
# 62                                   BASEMENTAREA_MEDI     2
# 360                          ACTIVE_AMT_CREDIT_SUM_SUM     2
# 58                                     LIVINGAREA_MODE     2
# 363                     ACTIVE_AMT_CREDIT_SUM_DEBT_SUM     2
# 483                              PREV_NC_LOAN_TERM_MAX     2
# 361                     ACTIVE_AMT_CREDIT_SUM_DEBT_MAX     2
# 410                     CLOSED_AMT_CREDIT_SUM_DEBT_SUM     2
# 767           INSAGG_INS_N_PREV_CNT_TOT_INSTALMENT_VAR     2
# 506       PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN     2
# 755                 INSAGG_INS_N_PREV_CNT_PROLONG_MEAN     2
# 48                                   BASEMENTAREA_MODE     3
# 47                                     APARTMENTS_MODE     4
# 480                               PREV_CNT_PAYMENT_SUM     5
# 642                 PREV_N_CREDIT_TYPE_Cash loans_MEAN     6
# 784                         INS_DAYS_ENTRY_PAYMENT_MAX     7
# 720                           REFUSED_AMT_ANNUITY_MEAN     8
# 694                           APPROVED_CNT_PAYMENT_SUM     9
# 766           INSAGG_INS_N_PREV_CNT_TOT_INSTALMENT_SUM     9
# 484                             PREV_NC_LOAN_TERM_MEAN    11
# 778                     INSAGG_INS_N_PREV_LOAN_AGE_MIN    12
# 765          INSAGG_INS_N_PREV_CNT_TOT_INSTALMENT_MEAN    12
# 296                       BUR_AMT_CREDIT_SUM_LIMIT_MAX    15
# 769         INSAGG_INS_N_PREV_LAST_DAYS_INSTALMENT_MAX    15
# 376                    ACTIVE_MONTHS_BALANCE_SIZE_MEAN    15
# 745                           REFUSED_CNT_PAYMENT_MEAN    17
# 335                   BUR_CREDIT_TYPE_Credit card_MEAN    18
# 691                         APPROVED_DAYS_DECISION_MAX    18
# 829                    CC_AMT_DRAWINGS_ATM_CURRENT_VAR    20
# 816                                 CC_AMT_BALANCE_MAX    20
# 334                    BUR_CREDIT_TYPE_Cash loans_MEAN    22
# 698                         APPROVED_NC_LOAN_TERM_MEAN    23
# 697                          APPROVED_NC_LOAN_TERM_MAX    24
# 892                   CC_CNT_DRAWINGS_POS_CURRENT_MEAN    24
# 475                        PREV_RATE_DOWN_PAYMENT_MEAN    26
# 866                               CC_AMT_RECIVABLE_MAX    27
# 871                        CC_AMT_TOTAL_RECEIVABLE_MAX    28
# 723                       REFUSED_AMT_APPLICATION_MEAN    29
# 679               APPROVED_N_CREDIT_PROLONG_RATIO_MEAN    30
# 801                             POS_MONTHS_BALANCE_MAX    31
# 587                     PREV_NAME_PORTFOLIO_Cards_MEAN    32
# 437              CLOSED_N_BUR_AMT_CREDIT_DEBT_RATE_MIN    32
# 297                      BUR_AMT_CREDIT_SUM_LIMIT_MEAN    34
# 467                          PREV_AMT_DOWN_PAYMENT_MIN    35
# 350                     ACTIVE_DAYS_CREDIT_ENDDATE_MIN    36
# 725                             REFUSED_AMT_CREDIT_MAX    37
# 262                             EMERGENCYSTATE_MODE_No    37
# 726                            REFUSED_AMT_CREDIT_MEAN    39
# 462                       PREV_N_ADJ_INTEREST_EVAL_VAR    40
# 762          INSAGG_INS_N_PREV_INS_AMT_MAX_OVERDUE_VAR    41
# 847                    CC_AMT_INST_MIN_REGULARITY_MEAN    42
# 874                        CC_AMT_TOTAL_RECEIVABLE_VAR    43
# 823                     CC_AMT_CREDIT_LIMIT_ACTUAL_SUM    45
# 458                        PREV_N_ADJ_CREDIT_RATIO_VAR    45
# 741                       REFUSED_AMT_GOODS_PRICE_MEAN    45
# 439             CLOSED_N_BUR_AMT_CREDIT_DEBT_RATE_MEAN    47
# 624          PREV_PRODUCT_COMBINATION_Card Street_MEAN    48
# 110                             N_CNT_PREV_REJECTED_HC    49
# 861                    CC_AMT_RECEIVABLE_PRINCIPAL_MAX    49
# 846                     CC_AMT_INST_MIN_REGULARITY_MAX    52
# 252                      HOUSETYPE_MODE_block of flats    52
# 454                        PREV_N_APP_CREDIT_RATIO_VAR    52
# 894                    CC_CNT_DRAWINGS_POS_CURRENT_VAR    54
# 438              CLOSED_N_BUR_AMT_CREDIT_DEBT_RATE_MAX    55
# 732                     REFUSED_N_ADJ_CREDIT_RATIO_MAX    56
# 764           INSAGG_INS_N_PREV_CNT_TOT_INSTALMENT_MAX    57
# 812                             CC_MONTHS_BALANCE_MEAN    58
# 878                    CC_CNT_DRAWINGS_ATM_CURRENT_SUM    59
# 719                            REFUSED_AMT_ANNUITY_MAX    59
# 392              ACTIVE_N_BUR_AMT_CREDIT_DEBT_RATE_VAR    61
# 805                                    POS_SK_DPD_MEAN    62
# 693                          APPROVED_CNT_PAYMENT_MEAN    63
# 833                        CC_AMT_DRAWINGS_CURRENT_SUM    64
# 50                                    YEARS_BUILD_MODE    66
# 420                      CLOSED_CNT_CREDIT_PROLONG_SUM    66
# 36                                     YEARS_BUILD_AVG    66
# 319                 BUR_N_BUR_AMT_CREDIT_DEBT_RATE_MIN    68
# 678                APPROVED_N_CREDIT_PROLONG_RATIO_MAX    69
# 672                    APPROVED_N_ADJ_CREDIT_RATIO_VAR    70
# 777      INSAGG_INS_N_PREV_EARLINESS_OVERDUE_RATIO_VAR    70
# 740                        REFUSED_AMT_GOODS_PRICE_MAX    72
# 735                    REFUSED_N_ADJ_INTEREST_EVAL_MIN    73
# 676                   APPROVED_N_ADJ_INTEREST_EVAL_VAR    74
# 303                         BUR_MONTHS_BALANCE_MIN_MIN    74
# 852                        CC_AMT_PAYMENT_CURRENT_MEAN    76
# 590                       PREV_NAME_PORTFOLIO_POS_MEAN    77
# 415                   CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN    78
# 681                      APPROVED_AMT_DOWN_PAYMENT_MIN    78
# 595                 PREV_NAME_PRODUCT_TYPE_x-sell_MEAN    80
# 870                        CC_AMT_TOTAL_RECEIVABLE_MIN    81
# 585                  PREV_NAME_GOODS_CATEGORY_XNA_MEAN    82
# 826                    CC_AMT_DRAWINGS_ATM_CURRENT_MAX    83
# 810                              CC_MONTHS_BALANCE_MIN    84
# 505        PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN    85
# 441              CLOSED_N_BUR_AMT_CREDIT_DEBT_RATE_VAR    86
# 70                                       LANDAREA_MEDI    87
# 56                                       LANDAREA_MODE    88
# 259                           WALLSMATERIAL_MODE_Panel    89
# 465                   PREV_N_CREDIT_PROLONG_RATIO_MEAN    90
# 408                     CLOSED_AMT_CREDIT_SUM_DEBT_MAX    91
# 634  PREV_PRODUCT_COMBINATION_POS household without...    91
# 857                  CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN    93
# 611           PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN    94
# 41                                       FLOORSMIN_AVG    94
# 649         PREV_N_CONTRACT_STATUS_REJECTED_LIMIT_MEAN    96
# 747                            REFUSED_CNT_PAYMENT_VAR    97
# 123                                    N_CNT_BUR_LOANS    98
# 851                         CC_AMT_PAYMENT_CURRENT_MAX    99
# 60                                  NONLIVINGAREA_MODE   100
# 730                     REFUSED_N_APP_CREDIT_RATIO_VAR   101
# 125                                    N_CNT_TOT_LOANS   101
# 74                                  NONLIVINGAREA_MEDI   103
# 856                   CC_AMT_PAYMENT_TOTAL_CURRENT_MAX   105
# 545        PREV_CODE_REJECT_REASON_REJECTED_LIMIT_MEAN   105
# 722                        REFUSED_AMT_APPLICATION_MAX   105
# 700                          APPROVED_NC_LOAN_TERM_VAR   107
# 46                                   NONLIVINGAREA_AVG   108
# 569            PREV_NAME_GOODS_CATEGORY_Furniture_MEAN   109
# 57                               LIVINGAPARTMENTS_MODE   110
# 610  PREV_NAME_SELLER_INDUSTRY_Consumer electronics...   111
# 637  PREV_PRODUCT_COMBINATION_POS mobile with inter...   112
# 819                                 CC_AMT_BALANCE_VAR   113
# 69                                      FLOORSMIN_MEDI   114
# 65                                     COMMONAREA_MEDI   114
# 897                  CC_CNT_INSTALMENT_MATURE_CUM_MEAN   116
# 814                              CC_MONTHS_BALANCE_VAR   117
# 630    PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN   118
# 757                  INSAGG_INS_N_PREV_CNT_PROLONG_VAR   119
# 42                                        LANDAREA_AVG   120
# 71                               LIVINGAPARTMENTS_MEDI   121
# 689                    APPROVED_RATE_DOWN_PAYMENT_MEAN   122
# 869                               CC_AMT_RECIVABLE_VAR   123
# 51                                     COMMONAREA_MODE   124
# 37                                      COMMONAREA_AVG   125
# 64                                    YEARS_BUILD_MEDI   126
# 497                               PREV_NC_LOAN_AGE_MIN   126
# 43                                LIVINGAPARTMENTS_AVG   128
# 734                     REFUSED_N_ADJ_CREDIT_RATIO_VAR   129
# 577               PREV_NAME_GOODS_CATEGORY_Mobile_MEAN   130
# 813                              CC_MONTHS_BALANCE_SUM   130
# 473                         PREV_RATE_DOWN_PAYMENT_MIN   132
# 899                   CC_CNT_INSTALMENT_MATURE_CUM_VAR   133
# 668                    APPROVED_N_APP_CREDIT_RATIO_VAR   134
# 849                     CC_AMT_INST_MIN_REGULARITY_VAR   134
# 414                    CLOSED_AMT_CREDIT_SUM_LIMIT_MAX   136
# 898                   CC_CNT_INSTALMENT_MATURE_CUM_SUM   137
# 859                   CC_AMT_PAYMENT_TOTAL_CURRENT_VAR   138
# 409                    CLOSED_AMT_CREDIT_SUM_DEBT_MEAN   139
# 486                              PREV_NC_LOAN_TERM_VAR   140
# 129                                N_INCOME_PER_PERSON   141
# 864                    CC_AMT_RECEIVABLE_PRINCIPAL_VAR   142
# 379                    ACTIVE_N_BUR_START_OBSERVED_MAX   143
# 423                    CLOSED_MONTHS_BALANCE_SIZE_MEAN   144
# 893                    CC_CNT_DRAWINGS_POS_CURRENT_SUM   145
# 429                   CLOSED_N_BUR_START_OBSERVED_MEAN   146
# 873                        CC_AMT_TOTAL_RECEIVABLE_SUM   147
# 753                  INSAGG_INS_N_PREV_CNT_PROLONG_MIN   148
# 854                         CC_AMT_PAYMENT_CURRENT_VAR   149
# 464                    PREV_N_CREDIT_PROLONG_RATIO_MAX   150
# 368                   ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN   150
# 421                      CLOSED_MONTHS_BALANCE_MIN_MIN   152
# 848                     CC_AMT_INST_MIN_REGULARITY_SUM   153
# 107                                N_CNT_PREV_APPROVED   154
# 711                           APPROVED_NC_LOAN_AGE_MIN   155
# 910                                         N_CC_COUNT   156
# 818                                 CC_AMT_BALANCE_SUM   156
# 626                 PREV_PRODUCT_COMBINATION_Cash_MEAN   158
# 828                    CC_AMT_DRAWINGS_ATM_CURRENT_SUM   159
# 853                         CC_AMT_PAYMENT_CURRENT_SUM   160
# 310                       BUR_N_BUR_START_OBSERVED_MAX   161
# 367                    ACTIVE_AMT_CREDIT_SUM_LIMIT_MAX   162
# 841                    CC_AMT_DRAWINGS_POS_CURRENT_MAX   163
# 67                                      ENTRANCES_MEDI   163
# 338                             BUR_STATUS_1_MEAN_MEAN   165
# 554               PREV_NAME_CLIENT_TYPE_Refreshed_MEAN   166
# 55                                      FLOORSMIN_MODE   167
# 313                       BUR_N_BUR_START_OBSERVED_VAR   168
# 424                     CLOSED_MONTHS_BALANCE_SIZE_SUM   169
# 309                       BUR_N_BUR_START_OBSERVED_MIN   170
# 860                    CC_AMT_RECEIVABLE_PRINCIPAL_MIN   171
# 39                                       ENTRANCES_AVG   172
# 369                    ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM   173
# 622                  PREV_NAME_YIELD_GROUP_middle_MEAN   174
# 616                 PREV_NAME_SELLER_INDUSTRY_XNA_MEAN   175
# 865                               CC_AMT_RECIVABLE_MIN   176
# 627    PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN   177
# 858                   CC_AMT_PAYMENT_TOTAL_CURRENT_SUM   177
# 868                               CC_AMT_RECIVABLE_SUM   179
# 815                                 CC_AMT_BALANCE_MIN   179
# 504            PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN   181
# 427                    CLOSED_N_BUR_START_OBSERVED_MIN   182
# 896                   CC_CNT_INSTALMENT_MATURE_CUM_MAX   183
# 842                   CC_AMT_DRAWINGS_POS_CURRENT_MEAN   184
# 532               PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN   185
# 591                       PREV_NAME_PORTFOLIO_XNA_MEAN   186
# 430                    CLOSED_N_BUR_START_OBSERVED_SUM   187
# 687                     APPROVED_RATE_DOWN_PAYMENT_MIN   188
# 804                                     POS_SK_DPD_MAX   189
# 863                    CC_AMT_RECEIVABLE_PRINCIPAL_SUM   191
# 763           INSAGG_INS_N_PREV_CNT_TOT_INSTALMENT_MIN   191
# 593                    PREV_NAME_PRODUCT_TYPE_XNA_MEAN   191
# 380                   ACTIVE_N_BUR_START_OBSERVED_MEAN   193
# 53                                      ENTRANCES_MODE   194
# 843                    CC_AMT_DRAWINGS_POS_CURRENT_SUM   194
# 428                    CLOSED_N_BUR_START_OBSERVED_MAX   196
# 23                             HOUR_APPR_PROCESS_START   197
# 307                    BUR_N_CREDIT_CLOSING_MONTHS_MAX   198
# 343                             BUR_STATUS_C_MEAN_MEAN   199
# 167                           OCCUPATION_TYPE_Laborers   200
# 555                PREV_NAME_CLIENT_TYPE_Repeater_MEAN   201
# 268                   N_PREV_LAST_DECISION_REJECTED_HC   202
# 374                      ACTIVE_MONTHS_BALANCE_MIN_MIN   203
# 301                                BUR_AMT_ANNUITY_SUM   204
# 531               PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN   205
# 306                        BUR_MONTHS_BALANCE_SIZE_SUM   205
# 589                      PREV_NAME_PORTFOLIO_Cash_MEAN   207
# 565  PREV_NAME_GOODS_CATEGORY_Consumer Electronics_...   208
# 696                          APPROVED_NC_LOAN_TERM_MIN   209
# 425                 CLOSED_N_CREDIT_CLOSING_MONTHS_MAX   209
# 316             BUR_N_BUR_EARLINESS_OVERDUE_RATIO_MEAN   211
# 822                    CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN   212
# 45                             NONLIVINGAPARTMENTS_AVG   213
# 318              BUR_N_BUR_EARLINESS_OVERDUE_RATIO_VAR   214
# 426                CLOSED_N_CREDIT_CLOSING_MONTHS_MEAN   215
# 431                    CLOSED_N_BUR_START_OBSERVED_VAR   216
# 754                  INSAGG_INS_N_PREV_CNT_PROLONG_MAX   217
# 482                              PREV_NC_LOAN_TERM_MIN   218
# 315              BUR_N_BUR_EARLINESS_OVERDUE_RATIO_MAX   218
# 677                APPROVED_N_CREDIT_PROLONG_RATIO_MIN   220
# 308                   BUR_N_CREDIT_CLOSING_MONTHS_MEAN   222
# 738                    REFUSED_N_ADJ_INTEREST_EVAL_VAR   222
# 293                     BUR_AMT_CREDIT_SUM_OVERDUE_MAX   222
# 604                       PREV_CHANNEL_TYPE_Stone_MEAN   224
# 312                       BUR_N_BUR_START_OBSERVED_SUM   225
# 602     PREV_CHANNEL_TYPE_Credit and cash offices_MEAN   225
# 111                          N_CNT_PREV_REJECTED_LIMIT   228
# 382                    ACTIVE_N_BUR_START_OBSERVED_VAR   228
# 381                    ACTIVE_N_BUR_START_OBSERVED_SUM   228
# 121                                   N_CNT_PREV_LOANS   230
# 378                    ACTIVE_N_BUR_START_OBSERVED_MIN   231
# 635  PREV_PRODUCT_COMBINATION_POS industry with int...   232
# 377                     ACTIVE_MONTHS_BALANCE_SIZE_SUM   232
# 317              BUR_N_BUR_EARLINESS_OVERDUE_RATIO_SUM   234
# 295                     BUR_AMT_CREDIT_SUM_OVERDUE_SUM   234
# 337                             BUR_STATUS_0_MEAN_MEAN   236
# 27                              REG_CITY_NOT_LIVE_CITY   237
# 491                PREV_NC_EARLINESS_OVERDUE_RATIO_VAR   237
# 73                            NONLIVINGAPARTMENTS_MEDI   239
# 463                    PREV_N_CREDIT_PROLONG_RATIO_MIN   240
# 632  PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN   240
# 344                             BUR_STATUS_X_MEAN_MEAN   242
# 59                            NONLIVINGAPARTMENTS_MODE   243
# 372                             ACTIVE_AMT_ANNUITY_SUM   244
# 283                        BUR_CREDIT_DAY_OVERDUE_MEAN   245
# 601                PREV_CHANNEL_TYPE_Country-wide_MEAN   245
# 496            PREV_NC_EARLINESS_OVERDUE_RATIO_DEF_VAR   247
# 597             PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN   248
# 300                               BUR_AMT_ANNUITY_MEAN   248
# 387           ACTIVE_N_BUR_EARLINESS_OVERDUE_RATIO_VAR   250
# 636  PREV_PRODUCT_COMBINATION_POS industry without ...   251
# 603            PREV_CHANNEL_TYPE_Regional / Local_MEAN   252
# 2                                         FLAG_OWN_CAR   253
# 824                     CC_AMT_CREDIT_LIMIT_ACTUAL_VAR   254
# 528           PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN   254
# 703           APPROVED_NC_EARLINESS_OVERDUE_RATIO_MEAN   256
# 717            APPROVED_NFLAG_INSURED_ON_APPROVAL_MEAN   257
# 821                     CC_AMT_CREDIT_LIMIT_ACTUAL_MAX   258
# 844                    CC_AMT_DRAWINGS_POS_CURRENT_VAR   259
# 494           PREV_NC_EARLINESS_OVERDUE_RATIO_DEF_MEAN   260
# 705            APPROVED_NC_EARLINESS_OVERDUE_RATIO_VAR   261
# 489               PREV_NC_EARLINESS_OVERDUE_RATIO_MEAN   262
# 633  PREV_PRODUCT_COMBINATION_POS household with in...   263
# 370                             ACTIVE_AMT_ANNUITY_MAX   263
# 294                    BUR_AMT_CREDIT_SUM_OVERDUE_MEAN   265
# 417                             CLOSED_AMT_ANNUITY_MAX   265
# 299                                BUR_AMT_ANNUITY_MAX   267
# 106                         AMT_REQ_CREDIT_BUREAU_YEAR   268
# 625          PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN   269
# 76                            OBS_30_CNT_SOCIAL_CIRCLE   270
# 282                         BUR_CREDIT_DAY_OVERDUE_MAX   271
# 503                PREV_NFLAG_INSURED_ON_APPROVAL_MEAN   272
# 365                 ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN   273
# 710        APPROVED_NC_EARLINESS_OVERDUE_RATIO_DEF_VAR   274
# 339                             BUR_STATUS_2_MEAN_MEAN   274
# 418                            CLOSED_AMT_ANNUITY_MEAN   276
# 371                            ACTIVE_AMT_ANNUITY_MEAN   277
# 271                N_PREV_LAST_DECISION_REJECTED_SCOFR   278
# 820                     CC_AMT_CREDIT_LIMIT_ACTUAL_MIN   279
# 163                            OCCUPATION_TYPE_Drivers   279
# 78                            OBS_60_CNT_SOCIAL_CIRCLE   281
# 85                                     FLAG_DOCUMENT_6   282
# 708       APPROVED_NC_EARLINESS_OVERDUE_RATIO_DEF_MEAN   282
# 563            PREV_NAME_GOODS_CATEGORY_Computers_MEAN   284
# 366                  ACTIVE_AMT_CREDIT_SUM_OVERDUE_SUM   284
# 384           ACTIVE_N_BUR_EARLINESS_OVERDUE_RATIO_MAX   286
# 562  PREV_NAME_GOODS_CATEGORY_Clothing and Accessor...   287
# 314              BUR_N_BUR_EARLINESS_OVERDUE_RATIO_MIN   288
# 716             APPROVED_NFLAG_INSURED_ON_APPROVAL_SUM   289
# 704            APPROVED_NC_EARLINESS_OVERDUE_RATIO_SUM   290
# 502                 PREV_NFLAG_INSURED_ON_APPROVAL_SUM   291
# 385          ACTIVE_N_BUR_EARLINESS_OVERDUE_RATIO_MEAN   292
# 600              PREV_CHANNEL_TYPE_Contact center_MEAN   293
# 493            PREV_NC_EARLINESS_OVERDUE_RATIO_DEF_MAX   294
# 490                PREV_NC_EARLINESS_OVERDUE_RATIO_SUM   295
# 536        PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN   296
# 707        APPROVED_NC_EARLINESS_OVERDUE_RATIO_DEF_MAX   297
# 77                            DEF_30_CNT_SOCIAL_CIRCLE   298
# 709        APPROVED_NC_EARLINESS_OVERDUE_RATIO_DEF_SUM   299
# 495            PREV_NC_EARLINESS_OVERDUE_RATIO_DEF_SUM   300
# 607            PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN   301
# 354                     ACTIVE_CREDIT_DAY_OVERDUE_MEAN   302
# 646                PREV_N_CONTRACT_STATUS_NOTUSED_MEAN   303
# 4                                         CNT_CHILDREN   304
# 628     PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN   305
# 79                            DEF_60_CNT_SOCIAL_CIRCLE   306
# 702            APPROVED_NC_EARLINESS_OVERDUE_RATIO_MAX   307
# 907                                 CC_SK_DPD_DEF_MEAN   308
# 364                  ACTIVE_AMT_CREDIT_SUM_OVERDUE_MAX   310
# 353                      ACTIVE_CREDIT_DAY_OVERDUE_MAX   310
# 386           ACTIVE_N_BUR_EARLINESS_OVERDUE_RATIO_SUM   310
# 20                                     CNT_FAM_MEMBERS   312
# 811                              CC_MONTHS_BALANCE_MAX   313
# 383           ACTIVE_N_BUR_EARLINESS_OVERDUE_RATIO_MIN   314
# 903                                      CC_SK_DPD_SUM   315
# 488                PREV_NC_EARLINESS_OVERDUE_RATIO_MAX   316
# 560          PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN   317
# 162                         OCCUPATION_TYPE_Core staff   318
# 647        PREV_N_CONTRACT_STATUS_REJECTED_CLIENT_MEAN   319
# 340                             BUR_STATUS_3_MEAN_MEAN   321
# 546          PREV_CODE_REJECT_REASON_REJECTED_SCO_MEAN   321
# 650           PREV_N_CONTRACT_STATUS_REJECTED_SCO_MEAN   321
# 889                  CC_CNT_DRAWINGS_OTHER_CURRENT_VAR   323
# 629  PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN   323
# 838                  CC_AMT_DRAWINGS_OTHER_CURRENT_SUM   325
# 706        APPROVED_NC_EARLINESS_OVERDUE_RATIO_DEF_MIN   326
# 887                 CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN   327
# 136                     NAME_INCOME_TYPE_State servant   328
# 904                                      CC_SK_DPD_VAR   329
# 302                         BUR_CNT_CREDIT_PROLONG_SUM   330
# 609        PREV_NAME_SELLER_INDUSTRY_Construction_MEAN   332
# 543       PREV_CODE_REJECT_REASON_REJECTED_CLIENT_MEAN   332
# 908                                  CC_SK_DPD_DEF_SUM   332
# 197                     ORGANIZATION_TYPE_Construction   334
# 29                             LIVE_CITY_NOT_WORK_CITY   335
# 638  PREV_PRODUCT_COMBINATION_POS mobile without in...   336
# 839                  CC_AMT_DRAWINGS_OTHER_CURRENT_VAR   337
# 133              NAME_INCOME_TYPE_Commercial associate   338
# 250                FONDKAPREMONT_MODE_reg oper account   339
# 157                        OCCUPATION_TYPE_Accountants   339
# 148            NAME_FAMILY_STATUS_Single / not married   341
# 902                                     CC_SK_DPD_MEAN   342
# 886                  CC_CNT_DRAWINGS_OTHER_CURRENT_MAX   343
# 580  PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipm...   344
# 830                        CC_AMT_DRAWINGS_CURRENT_MIN   345
# 260                    WALLSMATERIAL_MODE_Stone, brick   347
# 105                          AMT_REQ_CREDIT_BUREAU_QRT   347
# 175                        OCCUPATION_TYPE_Sales staff   347
# 232                    ORGANIZATION_TYPE_Self-employed   350
# 529      PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN   350
# 639  PREV_PRODUCT_COMBINATION_POS other with intere...   350
# 909                                  CC_SK_DPD_DEF_VAR   352
# 855                   CC_AMT_PAYMENT_TOTAL_CURRENT_MIN   353
# 564  PREV_NAME_GOODS_CATEGORY_Construction Material...   354
# 18                                          FLAG_PHONE   355
# 422                      CLOSED_MONTHS_BALANCE_MAX_MAX   356
# 331                BUR_CREDIT_CURRENCY_currency 3_MEAN   357
# 104                          AMT_REQ_CREDIT_BUREAU_MON   357
# 341                             BUR_STATUS_4_MEAN_MEAN   359
# 109                         N_CNT_PREV_REJECTED_CLIENT   360
# 895                   CC_CNT_INSTALMENT_MATURE_CUM_MIN   360
# 327                        BUR_CREDIT_ACTIVE_Sold_MEAN   362
# 112                            N_CNT_PREV_REJECTED_SCO   363
# 612            PREV_NAME_SELLER_INDUSTRY_Industry_MEAN   363
# 836                  CC_AMT_DRAWINGS_OTHER_CURRENT_MAX   365
# 188                 WEEKDAY_APPR_PROCESS_START_TUESDAY   366
# 837                 CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN   367
# 146                         NAME_FAMILY_STATUS_Married   368
# 492            PREV_NC_EARLINESS_OVERDUE_RATIO_DEF_MIN   369
# 524             PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN   370
# 373                      ACTIVE_CNT_CREDIT_PROLONG_SUM   370
# 583             PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN   372
# 906                                  CC_SK_DPD_DEF_MAX   373
# 169                           OCCUPATION_TYPE_Managers   373
# 901                                      CC_SK_DPD_MAX   375
# 551          PREV_CODE_REJECT_REASON_REJECTED_XNA_MEAN   377
# 890                    CC_CNT_DRAWINGS_POS_CURRENT_MIN   377
# 653         PREV_N_CONTRACT_STATUS_REJECTED_VERIF_MEAN   377
# 875                    CC_CNT_DRAWINGS_ATM_CURRENT_MIN   379
# 342                             BUR_STATUS_5_MEAN_MEAN   380
# 850                         CC_AMT_PAYMENT_CURRENT_MIN   381
# 165              OCCUPATION_TYPE_High skill tech staff   382
# 3                                      FLAG_OWN_REALTY   382
# 195           ORGANIZATION_TYPE_Business Entity Type 3   384
# 845                     CC_AMT_INST_MIN_REGULARITY_MIN   385
# 156                     NAME_HOUSING_TYPE_With parents   386
# 578    PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN   387
# 561     PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN   388
# 599  PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN   388
# 558   PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN   390
# 87                                     FLAG_DOCUMENT_8   390
# 540  PREV_NAME_PAYMENT_TYPE_Non-cash from your acco...   392
# 187                WEEKDAY_APPR_PROCESS_START_THURSDAY   393
# 193           ORGANIZATION_TYPE_Business Entity Type 1   395
# 330                BUR_CREDIT_CURRENCY_currency 2_MEAN   395
# 888                  CC_CNT_DRAWINGS_OTHER_CURRENT_SUM   395
# 574              PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN   398
# 516         PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN   398
# 375                      ACTIVE_MONTHS_BALANCE_MAX_MAX   398
# 508  PREV_NAME_CASH_LOAN_PURPOSE_Building a house o...   400
# 581    PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN   401
# 840                    CC_AMT_DRAWINGS_POS_CURRENT_MIN   402
# 606     PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN   403
# 189               WEEKDAY_APPR_PROCESS_START_WEDNESDAY   404
# 880                        CC_CNT_DRAWINGS_CURRENT_MIN   405
# 153              NAME_HOUSING_TYPE_Municipal apartment   406
# 145                  NAME_FAMILY_STATUS_Civil marriage   406
# 266                       N_PREV_LAST_DECISION_NOTUSED   408
# 304                         BUR_MONTHS_BALANCE_MAX_MAX   409
# 152                NAME_HOUSING_TYPE_House / apartment   410
# 147                       NAME_FAMILY_STATUS_Separated   411
# 25                          REG_REGION_NOT_WORK_REGION   412
# 255                           WALLSMATERIAL_MODE_Block   413
# 701            APPROVED_NC_EARLINESS_OVERDUE_RATIO_MIN   414
# 108                                 N_CNT_PREV_NOTUSED   416
# 116                            N_CNT_PREV_REJECTED_XNA   416
# 143                NAME_EDUCATION_TYPE_Lower secondary   416
# 269                N_PREV_LAST_DECISION_REJECTED_LIMIT   418
# 183                  WEEKDAY_APPR_PROCESS_START_FRIDAY   419
# 598                  PREV_CHANNEL_TYPE_Car dealer_MEAN   420
# 549        PREV_CODE_REJECT_REASON_REJECTED_VERIF_MEAN   421
# 229                           ORGANIZATION_TYPE_School   422
# 525  PREV_NAME_CASH_LOAN_PURPOSE_Payments on other ...   423
# 654           PREV_N_CONTRACT_STATUS_REJECTED_XNA_MEAN   424
# 218                     ORGANIZATION_TYPE_Kindergarten   425
# 19                                          FLAG_EMAIL   425
# 184                  WEEKDAY_APPR_PROCESS_START_MONDAY   427
# 325                    BUR_CREDIT_ACTIVE_Bad debt_MEAN   428
# 142              NAME_EDUCATION_TYPE_Incomplete higher   429
# 514  PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_...   430
# 241                    ORGANIZATION_TYPE_Trade: type 7   430
# 16                                     FLAG_WORK_PHONE   432
# 245                ORGANIZATION_TYPE_Transport: type 4   433
# 150                           NAME_FAMILY_STATUS_Widow   434
# 177                     OCCUPATION_TYPE_Security staff   435
# 329                BUR_CREDIT_CURRENCY_currency 1_MEAN   436
# 517  PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_...   437
# 115                          N_CNT_PREV_REJECTED_VERIF   438
# 155                 NAME_HOUSING_TYPE_Rented apartment   439
# 522          PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN   440
# 182                            OCCUPATION_TYPE_Working   440
# 160               OCCUPATION_TYPE_Commercial associate   442
# 223                            ORGANIZATION_TYPE_Other   442
# 168                 OCCUPATION_TYPE_Low-skill Laborers   444
# 513  PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN   445
# 487                PREV_NC_EARLINESS_OVERDUE_RATIO_MIN   446
# 186                  WEEKDAY_APPR_PROCESS_START_SUNDAY   447
# 251           FONDKAPREMONT_MODE_reg oper spec account   448
# 249                FONDKAPREMONT_MODE_org spec account   449
# 521           PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN   450
# 203                          ORGANIZATION_TYPE_Housing   451
# 161                      OCCUPATION_TYPE_Cooking staff   452
# 579                PREV_NAME_GOODS_CATEGORY_Other_MEAN   453
# 576             PREV_NAME_GOODS_CATEGORY_Medicine_MEAN   454
# 185                WEEKDAY_APPR_PROCESS_START_SATURDAY   454
# 26                         LIVE_REGION_NOT_WORK_REGION   456
# 806                                 POS_SK_DPD_DEF_MIN   457
# 556                     PREV_NAME_CLIENT_TYPE_XNA_MEAN   458
# 253                    HOUSETYPE_MODE_specific housing   458
# 230                         ORGANIZATION_TYPE_Security   460
# 803                                     POS_SK_DPD_MIN   461
# 523  PREV_NAME_CASH_LOAN_PURPOSE_Money for a third ...   462
# 539  PREV_NAME_PAYMENT_TYPE_Cashless from the accou...   463
# 825                    CC_AMT_DRAWINGS_ATM_CURRENT_MIN   464
# 588                      PREV_NAME_PORTFOLIO_Cars_MEAN   465
# 248                   FONDKAPREMONT_MODE_not specified   466
# 263                            EMERGENCYSTATE_MODE_Yes   467
# 570            PREV_NAME_GOODS_CATEGORY_Gardening_MEAN   468
# 103                         AMT_REQ_CREDIT_BUREAU_WEEK   469
# 228                       ORGANIZATION_TYPE_Restaurant   470
# 571            PREV_NAME_GOODS_CATEGORY_Homewares_MEAN   470
# 274                  N_PREV_LAST_DECISION_REJECTED_XNA   472
# 171                     OCCUPATION_TYPE_Medicine staff   473
# 221                         ORGANIZATION_TYPE_Military   473
# 173              OCCUPATION_TYPE_Private service staff   475
# 332                BUR_CREDIT_CURRENCY_currency 4_MEAN   475
# 267               N_PREV_LAST_DECISION_REJECTED_CLIENT   477
# 24                          REG_REGION_NOT_LIVE_REGION   477
# 233                         ORGANIZATION_TYPE_Services   479
# 237                    ORGANIZATION_TYPE_Trade: type 3   480
# 102                          AMT_REQ_CREDIT_BUREAU_DAY   481
# 178                      OCCUPATION_TYPE_State servant   482
# 154                 NAME_HOUSING_TYPE_Office apartment   488
# 270                  N_PREV_LAST_DECISION_REJECTED_SCO   488
# 254                      HOUSETYPE_MODE_terraced house   488
# 159                     OCCUPATION_TYPE_Cleaning staff   488
# 204                 ORGANIZATION_TYPE_Industry: type 1   488
# 566         PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN   488
# 652        PREV_N_CONTRACT_STATUS_REJECTED_SYSTEM_MEAN   488
# 613             PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN   488
# 567            PREV_NAME_GOODS_CATEGORY_Education_MEAN   488
# 84                                     FLAG_DOCUMENT_5   488
# 94                                    FLAG_DOCUMENT_15   488
# 512     PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN   488
# 509  PREV_NAME_CASH_LOAN_PURPOSE_Business developme...   496
# 166                           OCCUPATION_TYPE_IT staff   496
# 258                          WALLSMATERIAL_MODE_Others   496
# 225                           ORGANIZATION_TYPE_Postal   500
# 568              PREV_NAME_GOODS_CATEGORY_Fitness_MEAN   500
# 211                 ORGANIZATION_TYPE_Industry: type 4   500
# 559              PREV_NAME_GOODS_CATEGORY_Animals_MEAN   500
# 518         PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN   500
# 234                          ORGANIZATION_TYPE_Telecom   509
# 256                           WALLSMATERIAL_MODE_Mixed   509
# 243                ORGANIZATION_TYPE_Transport: type 2   509
# 174                      OCCUPATION_TYPE_Realty agents   509
# 244                ORGANIZATION_TYPE_Transport: type 3   509
# 220                         ORGANIZATION_TYPE_Medicine   509
# 575     PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN   509
# 582              PREV_NAME_GOODS_CATEGORY_Tourism_MEAN   509
# 226                          ORGANIZATION_TYPE_Realtor   509
# 261                          WALLSMATERIAL_MODE_Wooden   509
# 511  PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday h...   509
# 640  PREV_PRODUCT_COMBINATION_POS others without in...   509
# 216                 ORGANIZATION_TYPE_Industry: type 9   509
# 217                        ORGANIZATION_TYPE_Insurance   520
# 206                ORGANIZATION_TYPE_Industry: type 11   520
# 192                             ORGANIZATION_TYPE_Bank   520
# 615             PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN   520
# 194           ORGANIZATION_TYPE_Business Entity Type 2   520
# 90                                    FLAG_DOCUMENT_11   520
# 510   PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN   520
# 584               PREV_NAME_GOODS_CATEGORY_Weapon_MEAN   520
# 573            PREV_NAME_GOODS_CATEGORY_Insurance_MEAN   520
# 201                       ORGANIZATION_TYPE_Government   520
# 176                        OCCUPATION_TYPE_Secretaries   526
# 231              ORGANIZATION_TYPE_Security Ministries   533
# 240                    ORGANIZATION_TYPE_Trade: type 6   533
# 191                      ORGANIZATION_TYPE_Agriculture   533
# 199                      ORGANIZATION_TYPE_Electricity   533
# 95                                    FLAG_DOCUMENT_16   533
# 214                 ORGANIZATION_TYPE_Industry: type 7   533
# 151                  NAME_HOUSING_TYPE_Co-op apartment   533
# 114                         N_CNT_PREV_REJECTED_SYSTEM   533
# 527  PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name th...   533
# 530  PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / h...   533
# 257                      WALLSMATERIAL_MODE_Monolithic   533
# 548       PREV_CODE_REJECT_REASON_REJECTED_SYSTEM_MEAN   533
# 224                           ORGANIZATION_TYPE_Police   533
# 219                   ORGANIZATION_TYPE_Legal Services   533
# 526  PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electr...   543
# 99                                    FLAG_DOCUMENT_20   543
# 265                          N_PREV_LAST_DECISION_NONE   543
# 212                 ORGANIZATION_TYPE_Industry: type 5   543
# 519  PREV_NAME_CASH_LOAN_PURPOSE_Gasification / wat...   543
# 17                                    FLAG_CONT_MOBILE   543
# 238                    ORGANIZATION_TYPE_Trade: type 4   586
# 202                            ORGANIZATION_TYPE_Hotel   586
# 96                                    FLAG_DOCUMENT_17   586
# 246                       ORGANIZATION_TYPE_University   586
# 242                ORGANIZATION_TYPE_Transport: type 1   586
# 239                    ORGANIZATION_TYPE_Trade: type 5   586
# 655                    PREV_N_CONTRACT_STATUS_nan_MEAN   586
# 134                   NAME_INCOME_TYPE_Maternity leave   586
# 235                    ORGANIZATION_TYPE_Trade: type 1   586
# 205                ORGANIZATION_TYPE_Industry: type 10   586
# 207                ORGANIZATION_TYPE_Industry: type 12   586
# 208                ORGANIZATION_TYPE_Industry: type 13   586
# 209                 ORGANIZATION_TYPE_Industry: type 2   586
# 905                                  CC_SK_DPD_DEF_MIN   586
# 210                 ORGANIZATION_TYPE_Industry: type 3   586
# 213                 ORGANIZATION_TYPE_Industry: type 6   586
# 900                                      CC_SK_DPD_MIN   586
# 236                    ORGANIZATION_TYPE_Trade: type 2   586
# 215                 ORGANIZATION_TYPE_Industry: type 8   586
# 222                           ORGANIZATION_TYPE_Mobile   586
# 88                                     FLAG_DOCUMENT_9   586
# 89                                    FLAG_DOCUMENT_10   586
# 885                  CC_CNT_DRAWINGS_OTHER_CURRENT_MIN   586
# 227                         ORGANIZATION_TYPE_Religion   586
# 91                                    FLAG_DOCUMENT_12   586
# 92                                    FLAG_DOCUMENT_13   586
# 93                                    FLAG_DOCUMENT_14   586
# 86                                     FLAG_DOCUMENT_7   586
# 97                                    FLAG_DOCUMENT_18   586
# 200                        ORGANIZATION_TYPE_Emergency   586
# 644                        PREV_N_CREDIT_TYPE_nan_MEAN   586
# 552                   PREV_CODE_REJECT_REASON_nan_MEAN   586
# 14                                          FLAG_MOBIL   586
# 542                    PREV_NAME_PAYMENT_TYPE_nan_MEAN   586
# 537                 PREV_NAME_CONTRACT_STATUS_nan_MEAN   586
# 170                    OCCUPATION_TYPE_Maternity leave   586
# 533               PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN   586
# 748                           REFUSED_NC_LOAN_TERM_SUM   586
# 164                           OCCUPATION_TYPE_HR staff   586
# 749             REFUSED_NC_EARLINESS_OVERDUE_RATIO_SUM   586
# 81                                     FLAG_DOCUMENT_2   586
# 750         REFUSED_NC_EARLINESS_OVERDUE_RATIO_DEF_SUM   586
# 751                            REFUSED_NC_LOAN_AGE_SUM   586
# 752              REFUSED_NFLAG_INSURED_ON_APPROVAL_SUM   586
# 520             PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN   586
# 158                        OCCUPATION_TYPE_Businessman   586
# 515       PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN   586
# 149                         NAME_FAMILY_STATUS_Unknown   586
# 507                   PREV_NAME_CONTRACT_TYPE_nan_MEAN   586
# 140                NAME_EDUCATION_TYPE_Academic degree   586
# 138                        NAME_INCOME_TYPE_Unemployed   586
# 137                           NAME_INCOME_TYPE_Student   586
# 345                           BUR_STATUS_nan_MEAN_MEAN   586
# 336                           BUR_CREDIT_TYPE_nan_MEAN   586
# 333                       BUR_CREDIT_CURRENCY_nan_MEAN   586
# 557                     PREV_NAME_CLIENT_TYPE_nan_MEAN   586
# 641                  PREV_PRODUCT_COMBINATION_nan_MEAN   586
# 100                                   FLAG_DOCUMENT_21   586
# 623                     PREV_NAME_YIELD_GROUP_nan_MEAN   586
# 101                         AMT_REQ_CREDIT_BUREAU_HOUR   586
# 617                 PREV_NAME_SELLER_INDUSTRY_nan_MEAN   586
# 272               N_PREV_LAST_DECISION_REJECTED_SYSTEM   586
# 273                N_PREV_LAST_DECISION_REJECTED_VERIF   586
# 132                       NAME_INCOME_TYPE_Businessman   586
# 198                          ORGANIZATION_TYPE_Culture   586
# 614        PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN   586
# 98                                    FLAG_DOCUMENT_19   586
# 196                         ORGANIZATION_TYPE_Cleaning   586
# 190                      ORGANIZATION_TYPE_Advertising   586
# 605                         PREV_CHANNEL_TYPE_nan_MEAN   586
# 596                    PREV_NAME_PRODUCT_TYPE_nan_MEAN   586
# 592                       PREV_NAME_PORTFOLIO_nan_MEAN   586
# 586                  PREV_NAME_GOODS_CATEGORY_nan_MEAN   586
# 572   PREV_NAME_GOODS_CATEGORY_House Construction_MEAN   586
# 181               OCCUPATION_TYPE_Waiters/barmen staff   586
# 180                         OCCUPATION_TYPE_Unemployed   586
# 179                            OCCUPATION_TYPE_Student   586
# 328                         BUR_CREDIT_ACTIVE_nan_MEAN   586
# 835                  CC_AMT_DRAWINGS_OTHER_CURRENT_MIN   586
# 83                                     FLAG_DOCUMENT_4   586

# %%
# get support features
support = train.drop(columns=['TARGET']).columns[feat_selector.support_]

# %%
selected = []
selected = ['SK_ID_CURR'] + ['TARGET'] + support.tolist()

# %%
sel_app = application.filter(selected)

# %%
with open("Data/sel_app.pkl", mode="wb") as df:
    pickle.dump(sel_app, df)

# %%
del sel_app
del train
del application

# %% [markdown]
# ## Boruta Shap : perspective
# from BorutaShap import BorutaShap
# Feature_Selector = BorutaShap(importance_measure='shap',
#                               classification=False)
# Feature_Selector.fit(X=X_, y=y_, n_trials=100, random_state=0)
